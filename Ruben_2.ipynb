# %%
import tensorflow as tf
import os
from matplotlib import pyplot as plt
# from IPython import display
# from IPython.display import clear_output

from google.colab import drive
drive.mount('/content/drive/')
# path = "/content/drive/My Drive/HDSP/PnP-ADMM"
path = "/content/drive/My Drive/DATA"
os.chdir(path)

from os import listdir
from os.path import isfile, join

import numpy as np
import keras
import scipy.io
import pandas as pd
from scipy.io import loadmat

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.python.keras import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.models import *

#---------------------defined function used -------------------------------------------------------------------


# Defined protocol of input and ouput (it is recommended only read, not applied operator here, but it is possible)
def Input_image(image):
    images = loadmat(image).get('y')
    images = np.expand_dims(images,-1)
    # procesamiento
    return images/np.max(images)

def Oput_image(image):
    images = loadmat(image).get('y_m')
    images = np.expand_dims(images, -1)
    return images/np.max(images)

def load_sambles(data):
  data = data[['inimg']]
  inimg_name = list(data.iloc[:,0])
  samples = []
  for samp in inimg_name:
    samples.append(samp)
  return samples


class DataGenerator(tf.keras.utils.Sequence):
    def __init__(self, samples,PATH,batch_size=1,dim_input=(512, 512, 3), shuffle=True, dim_oput=(512, 512, 3)):
        'Initialization'
        self.dim_input = dim_input
        self.dim_oput = dim_oput
        self.batch_size = batch_size
        self.list_images = samples
        self.shuffle = shuffle
        self.PATH = PATH
        self.on_epoch_end()


    # falta __data_generation
    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(len(self.list_images) / self.batch_size)

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index * self.batch_size:(index + 1) * self.batch_size]

        # Find list of IDs
        images_name = [self.list_images[k] for k in indexes]

        # Generate data
        X, y = self.__data_generation(images_name)

        return X, y

    def on_epoch_end(self):
        'Update indexes after each epoch'
        self.indexes = np.arange(len(self.list_images))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, images_names):
        'Generates data containing batch_size samples'  # X : (n_samples, *dim, n_channels)
        # Initialization
        X = np.empty((self.batch_size, *self.dim_input))  # Array de numpy con zeros de tamaño
        y = np.empty((self.batch_size, *self.dim_oput))
        # Generate data
        for i, file_name in enumerate(images_names):
            # Store sample
            X[i,] = Input_image(self.PATH + '/' + file_name)
            # Store class
            y[i,] = Oput_image(self.PATH + '/' + file_name)
        return X, y



def Build_data_set(IMG_WIDTH,IMG_HEIGHT,L_bands,L_imput,BATCH_SIZE,PATH,split_v):

  # Random split
  data_dir_list = os.listdir(PATH)
  N = len(data_dir_list)
  train_df = pd.DataFrame(columns=['inimg'])
  test_df = pd.DataFrame(columns=['inimg'])
  randurls = np.copy(data_dir_list)
  train_n = round(N * split_v)
  np.random.shuffle(randurls)
  tr_urls = randurls[:train_n]
  ts_urls = randurls[train_n:N]
  for i in tr_urls:
      train_df = train_df.append({'inimg': i}, ignore_index=True)
  for i in ts_urls:
      test_df = test_df.append({'inimg': i}, ignore_index=True)

  params = {'dim_input': (IMG_WIDTH, IMG_HEIGHT, L_imput),
            'dim_oput': (IMG_WIDTH, IMG_HEIGHT, L_bands),
            'batch_size': BATCH_SIZE,
            'PATH': PATH,
            'shuffle': True}

  partition_Train = load_sambles(test_df)
  partition_Test = load_sambles(train_df)

  train_generator = DataGenerator(partition_Train, **params)
  test_generator = DataGenerator(partition_Test, **params)

  train_dataset = tf.data.Dataset.from_generator(
      lambda: train_generator,
      (tf.float32, tf.float32))

  test_dataset = tf.data.Dataset.from_generator(
      lambda: test_generator,
      (tf.float32, tf.float32))

  return train_dataset,test_dataset

def PSNR_Metric(y_true, y_pred):
  return tf.reduce_mean(tf.image.psnr(y_true,y_pred,tf.reduce_max(y_true)))

# os.environ["CUDA_VISIBLE_DEVICES"]= '1'
# gpus = tf.config.experimental.list_physical_devices('GPU')
# if gpus:
#   try:
#     # Currently, memory growth needs to be the same across GPUs
#     for gpu in gpus:
#       tf.config.experimental.set_memory_growth(gpu, True)
#     logical_gpus = tf.config.experimental.list_logical_devices('GPU')
#     print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
#   except RuntimeError as e:
#     # Memory growth must be set before GPUs have been initialized
#     print(e)

gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# !pwd
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))


#----------------------------- directory of the spectral data set -------------------------                              # for windows
BATCH_SIZE = 1; L_bands    = 1; L_imput    = 1;
from scipy.io import loadmat
# from recoverynet import *     # Net build


#########################################################################################

ARAD = False # @ {type:"boolean"} ### IF TRUE MODIFIY NETWORK
if ARAD:
  IMG_WIDTH = 286; IMG_HEIGHT = 256;
  path_files  = os.getcwd()+'/ARAD/Y'
  nI = 10
else:
  IMG_WIDTH = 535; IMG_HEIGHT = 512;
  path_files  = os.getcwd()+'/REAL/Y'
  nI = 14
reTrain = False # @ {type:"boolean"}
gf=0.0  # @ {type:"raw"}
awgn=25 # @ {type:"raw"}
lr = 1e-4# @ {type:"raw"}
batch =  nI# @ {type:"raw"}

norm_inp="NO-F"  # @ {type:"raw"}
norm_out="NO-F"  # @ {type:"raw"}
loss =  'mean_squared_error'# @ {type:"string"}
model_path=os.getcwd()
net = "NO-NO"
old_cp_dir=model_path+'/Weights/Ruben/' #@param {type:"raw"}
# if ARAD:
#     old_cp_dir += 'ARAD_'+str(gf)+'_'+str(awgn)+'_'+net+'/'
# else:
#     old_cp_dir += 'REAL/'




#########################################################################################

optimizad = tf.keras.optimizers.Adam(learning_rate=lr, amsgrad=False)

# model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
#     filepath=new_cp_path,
#     save_weights_only=True,
#     verbose=1,
#     save_freq='epoch',
#     monitor='PSNR_Metric',
#     mode='max',
#     save_best_only=True)



Y_inp = None
for s in range(nI):
  if norm_inp!="" and ARAD:
    Temp = np.array(loadmat(path_files + '/y_ideal_'+str(s+1)+'_'+norm_inp)['y_ideal'])
  else:
    Temp = np.array(loadmat(path_files + '/y_ideal_'+str(s+1))['y_ideal'])
  if Y_inp is None:
    Y_inp = np.expand_dims(Temp, 0)
  else:
    Y_inp = np.concatenate((Y_inp, np.expand_dims(Temp, 0)),0)

Y_oup = None
for s in range(nI):
  if norm_out!="" and ARAD:
    Temp = np.array(loadmat(path_files + '/y_real_m_'+str(s+1)+'_'+str(gf)+'_'+str(awgn)+'_'+norm_out)['y_real_m'])
  elif ARAD:
    Temp = np.array(loadmat(path_files + '/y_real_m_'+str(s+1)+'_'+str(gf)+'_'+str(awgn))['y_real_m'])
  else:
    Temp = np.array(loadmat(path_files + '/y_real_'+str(s+1))['y_real'])
  if Y_oup is None:
    Y_oup = np.expand_dims(Temp, 0)
  else:
    Y_oup = np.concatenate((Y_oup, np.expand_dims(Temp, 0)),0)

Y_inp = np.expand_dims(Y_inp, -1)
Y_oup = np.expand_dims(Y_oup, -1)
# Out:
# Mounted at /content/drive/
# Sun Aug 21 14:58:31 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Your runtime has 13.6 gigabytes of available RAM

# %%
#@markdown UNet - Base
def UNetL2(pretrained_weights=None, input_size=(256, 256, 12)):

    inputs = Input(input_size)
    L = 16;
    L_2 = 2 * L;
    L_3 = 3 * L;
    L_4 = 4 * L;
    conv1 = Conv2D(L, 3, activation='relu', padding='same', kernel_initializer='he_normal')(inputs)
    conv1 = Conv2D(L, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(L_2, 3, activation='relu', padding='same', kernel_initializer='he_normal')(pool1)
    conv2 = Conv2D(L_2, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(L_3, 3, activation='relu', padding='same', kernel_initializer='he_normal')(pool2)
    conv3 = Conv2D(L_3, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv3)
    # drop3 = Dropout(0.5)(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(L_4, 3, activation='relu', padding='same', kernel_initializer='he_normal')(pool3)
    conv4 = Conv2D(L_4, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv4)
    # drop4 = Dropout(0.5)(conv4)

    up5 = Conv2D(L_3, 2, activation='relu', padding='same', kernel_initializer='he_normal')(
        UpSampling2D(size=(2, 2))(conv4))
    up5 = Conv2DTranspose(L_3,[1,2],activation='relu')(up5)
    merge5 = concatenate([conv3, up5], axis=3)
    conv5 = Conv2D(L_3, 3, activation='relu', padding='same', kernel_initializer='he_normal')(merge5)
    conv5 = Conv2D(L_3, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv5)

    up6 = Conv2D(L_2, 2, activation='relu', padding='same', kernel_initializer='he_normal')(
        UpSampling2D(size=(2, 2))(conv5))
    up6 = Conv2DTranspose(L_2, [1, 2], activation='relu')(up6)
    merge6 = concatenate([conv2, up6], axis=3)
    conv6 = Conv2D(L_2, 3, activation='relu', padding='same', kernel_initializer='he_normal')(merge6)
    conv6 = Conv2D(L_2, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv6)

    up7 = Conv2D(L, 2, activation='relu', padding='same', kernel_initializer='he_normal')(
        UpSampling2D(size=(2, 2))(conv6))
    up7 = Conv2DTranspose(L, [1, 2], activation='relu')(up7) #OFF PARA ARAD
    merge7 = concatenate([conv1, up7], axis=3)
    conv7 = Conv2D(L, 3, activation='relu', padding='same', kernel_initializer='he_normal')(merge7)
    conv7 = Conv2D(L, 3, activation='relu', padding='same', kernel_initializer='he_normal', )(conv7)

    final = Conv2D(1, 1)(conv7)


    model = Model(inputs, final)

    if (pretrained_weights):
        model.load_weights(pretrained_weights)

    return model

# %%
epochs =  10# @param {type:"number"}

#-------------Net_model----------------------------------------------------------------
model = UNetL2(input_size=(IMG_HEIGHT,IMG_WIDTH,L_bands))
model.compile(optimizer=optimizad, loss=loss,metrics = [PSNR_Metric])
history = model.fit(x=Y_inp,y=Y_oup, epochs=epochs)#, callbacks=[model_checkpoint_callback])
last_psnr=history.history['PSNR_Metric'][-1]
best_psnr=np.max(history.history['PSNR_Metric'])
iter_psnr=history.history['PSNR_Metric'].index(best_psnr)
best_loss=np.min(history.history['loss'])
iter_loss=history.history['loss'].index(best_loss)
name="Base" # @param {type:"string"}
name+=', '+str(best_psnr)+', '+str(best_loss)+', '+str(epochs)+'.h5'
print(name)
model.save(old_cp_dir+name)

#.------------ seee the accfuracy---------------
plt.plot(history.history['loss'], label='loss')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.show()
plt.plot(history.history['PSNR_Metric'], label='PSNR_Metric')
plt.xlabel('Epoch')
plt.ylabel('PSNR_Metric')
plt.show()

# %%
#@markdown UNet - NO padd
def UNetL2(pretrained_weights=None, input_size=(256, 256, 12)):

    inputs = Input(input_size)
    L = 16;
    L_2 = 2 * L;
    L_3 = 3 * L;
    L_4 = 4 * L;
    conv1 = Conv2D(L, 3, activation='relu', kernel_initializer='he_normal')(inputs)
    conv1 = Conv2D(L, 3, activation='relu', kernel_initializer='he_normal')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(L_2, 3, activation='relu', kernel_initializer='he_normal')(pool1)
    conv2 = Conv2D(L_2, 3, activation='relu', kernel_initializer='he_normal')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(L_3, 3, activation='relu', kernel_initializer='he_normal')(pool2)
    conv3 = Conv2D(L_3, 3, activation='relu', kernel_initializer='he_normal')(conv3)
    # drop3 = Dropout(0.5)(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(L_4, 3, activation='relu', kernel_initializer='he_normal')(pool3)
    conv4 = Conv2D(L_4, 3, activation='relu', kernel_initializer='he_normal')(conv4)
    # drop4 = Dropout(0.5)(conv4)

    up5 = Conv2D(L_3, 2, activation='relu', kernel_initializer='he_normal')(
        UpSampling2D(size=(2, 2))(conv4))
    up5 = Conv2DTranspose(L_3,[1,2],activation='relu')(up5)
    up5 = tf.keras.layers.Resizing(121, 126, interpolation="bilinear", crop_to_aspect_ratio=False)(up5)

    merge5 = concatenate([conv3, up5], axis=3)
    conv5 = Conv2D(L_3, 3, activation='relu', kernel_initializer='he_normal')(merge5)
    conv5 = Conv2D(L_3, 3, activation='relu', kernel_initializer='he_normal')(conv5)

    up6 = Conv2D(L_2, 2, activation='relu', kernel_initializer='he_normal')(
        UpSampling2D(size=(2, 2))(conv5))
    up6 = Conv2DTranspose(L_2, [1, 2], activation='relu')(up6)
    up6 = tf.keras.layers.Resizing(250, 261, interpolation="bilinear", crop_to_aspect_ratio=False)(up6)
    merge6 = concatenate([conv2, up6], axis=3)
    conv6 = Conv2D(L_2, 3, activation='relu', kernel_initializer='he_normal')(merge6)
    conv6 = Conv2D(L_2, 3, activation='relu', kernel_initializer='he_normal')(conv6)

    up7 = Conv2D(L, 2, activation='relu', kernel_initializer='he_normal')(
        UpSampling2D(size=(2, 2))(conv6))
    up7 = Conv2DTranspose(L, [1, 2], activation='relu')(up7) #OFF PARA ARAD
    up7 = tf.keras.layers.Resizing(508, 531, interpolation="bilinear", crop_to_aspect_ratio=False)(up7)
    merge7 = concatenate([conv1, up7], axis=3)
    conv7 = Conv2D(L, 3, activation='relu', kernel_initializer='he_normal')(merge7)
    conv7 = Conv2D(L, 3, activation='relu', kernel_initializer='he_normal', )(conv7)
    conv7 = tf.keras.layers.Resizing(512, 535, interpolation="bilinear", crop_to_aspect_ratio=False)(conv7)
    final = Conv2D(1, 1)(conv7)


    model = Model(inputs, final)

    if (pretrained_weights):
        model.load_weights(pretrained_weights)

    return model

# %%
epochs =  1000# @param {type:"number"}

#-------------Net_model----------------------------------------------------------------
model = UNetL2(input_size=(IMG_HEIGHT,IMG_WIDTH,L_bands))
# model.summary()
model.compile(optimizer=optimizad, loss=loss,metrics = [PSNR_Metric])
history = model.fit(x=Y_inp,y=Y_oup, epochs=epochs)#, callbacks=[model_checkpoint_callback])
last_psnr=history.history['PSNR_Metric'][-1]
best_psnr=np.max(history.history['PSNR_Metric'])
iter_psnr=history.history['PSNR_Metric'].index(best_psnr)
best_loss=np.min(history.history['loss'])
iter_loss=history.history['loss'].index(best_loss)
name="No_Padding" # @param {type:"string"}
name+=', '+str(best_psnr)+', '+str(best_loss)+', '+str(epochs)+'.h5'
print(name)
model.save(old_cp_dir+name)

#.------------ seee the accfuracy---------------
plt.plot(history.history['loss'], label='loss')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.show()
plt.plot(history.history['PSNR_Metric'], label='PSNR_Metric')
plt.xlabel('Epoch')
plt.ylabel('PSNR_Metric')
plt.show()

# %%
#@markdown UNet - Variance Scaling Initializer - Padd - Batch - Resize
def UNetL2(pretrained_weights=None, input_size=(256, 256, 12)):

    init = tf.keras.initializers.VarianceScaling(
      scale=1.0,
      mode='fan_in',
      distribution='truncated_normal',
      seed=None
    )

    inputs = Input(input_size)
    L = 16;
    L_2 = 2 * L;
    L_3 = 3 * L;
    L_4 = 4 * L;
    conv1 = Conv2D(L, 3, activation='relu', padding='same', kernel_initializer=init)(inputs)
    conv1 = Conv2D(L, 3, activation='relu', padding='same', kernel_initializer=init)(conv1)
    conv1 = BatchNormalization()(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(L_2, 3, activation='relu', padding='same', kernel_initializer=init)(pool1)
    conv2 = Conv2D(L_2, 3, activation='relu', padding='same', kernel_initializer=init)(conv2)
    conv2 = BatchNormalization()(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(L_3, 3, activation='relu', padding='same', kernel_initializer=init)(pool2)
    conv3 = Conv2D(L_3, 3, activation='relu', padding='same', kernel_initializer=init)(conv3)
    conv3 = BatchNormalization()(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(L_4, 3, activation='relu', padding='same', kernel_initializer=init)(pool3)
    conv4 = Conv2D(L_4, 3, activation='relu', padding='same', kernel_initializer=init)(conv4)
    # drop4 = Dropout(0.5)(conv4)
    conv4 = BatchNormalization()(conv4)
    up5 = Conv2D(L_3, 2, activation='relu', padding='same', kernel_initializer=init)(
        UpSampling2D(size=(2, 2))(conv4))
    up5 = Conv2DTranspose(L_3,[1,2],activation='relu')(up5)
    up5 = tf.keras.layers.Resizing(128, 133, interpolation="bilinear", crop_to_aspect_ratio=False)(up5)

    merge5 = concatenate([conv3, up5], axis=3)
    conv5 = Conv2D(L_3, 3, activation='relu', padding='same', kernel_initializer=init)(merge5)
    conv5 = Conv2D(L_3, 3, activation='relu', padding='same', kernel_initializer=init)(conv5)
    conv5 = BatchNormalization()(conv5)
    up6 = Conv2D(L_2, 2, activation='relu', padding='same', kernel_initializer=init)(
        UpSampling2D(size=(2, 2))(conv5))
    up6 = Conv2DTranspose(L_2, [1, 2], activation='relu')(up6)
    up6 = tf.keras.layers.Resizing(256, 267, interpolation="bilinear", crop_to_aspect_ratio=False)(up6)
    merge6 = concatenate([conv2, up6], axis=3)
    conv6 = Conv2D(L_2, 3, activation='relu', padding='same', kernel_initializer=init)(merge6)
    conv6 = Conv2D(L_2, 3, activation='relu', padding='same', kernel_initializer=init)(conv6)
    conv6 = BatchNormalization()(conv6)
    up7 = Conv2D(L, 2, activation='relu', padding='same', kernel_initializer=init)(
        UpSampling2D(size=(2, 2))(conv6))
    up7 = Conv2DTranspose(L, [1, 2], activation='relu')(up7) #OFF PARA ARAD
    up7 = tf.keras.layers.Resizing(512, 535, interpolation="bilinear", crop_to_aspect_ratio=False)(up7)
    merge7 = concatenate([conv1, up7], axis=3)
    conv7 = Conv2D(L, 3, activation='relu', padding='same', kernel_initializer=init)(merge7)
    conv7 = Conv2D(L, 3, activation='relu', padding='same', kernel_initializer=init, )(conv7)
    conv7 = tf.keras.layers.Resizing(512, 535, interpolation="bilinear", crop_to_aspect_ratio=False)(conv7)
    
    final = Conv2D(1, 1)(conv7)


    model = Model(inputs, final)

    if (pretrained_weights):
        model.load_weights(pretrained_weights)

    return model

# %%
epochs =  1000# @param {type:"number"}

#-------------Net_model----------------------------------------------------------------
model = UNetL2(input_size=(IMG_HEIGHT,IMG_WIDTH,L_bands))
# model.summary()
model.compile(optimizer=optimizad, loss=loss,metrics = [PSNR_Metric])
history = model.fit(x=Y_inp,y=Y_oup, epochs=epochs)#, callbacks=[model_checkpoint_callback])
last_psnr=history.history['PSNR_Metric'][-1]
best_psnr=np.max(history.history['PSNR_Metric'])
iter_psnr=history.history['PSNR_Metric'].index(best_psnr)
best_loss=np.min(history.history['loss'])
iter_loss=history.history['loss'].index(best_loss)
name="VarScaInit_Padd_Batch" # @param {type:"string"}
name+=', '+str(best_psnr)+', '+str(best_loss)+', '+str(epochs)+'.h5'
print(name)
model.save(old_cp_dir+name)

#.------------ seee the accfuracy---------------
plt.plot(history.history['loss'], label='loss')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.show()
plt.plot(history.history['PSNR_Metric'], label='PSNR_Metric')
plt.xlabel('Epoch')
plt.ylabel('PSNR_Metric')
plt.show()

# %%
#@markdown UNet - Batch NO padd
def UNetL2(pretrained_weights=None, input_size=(256, 256, 12)):

    inputs = Input(input_size)
    L = 16;
    L_2 = 2 * L;
    L_3 = 3 * L;
    L_4 = 4 * L;
    conv1 = Conv2D(L, 3, activation='relu', kernel_initializer='he_normal')(inputs)
    conv1 = Conv2D(L, 3, activation='relu', kernel_initializer='he_normal')(conv1)
    conv1 = BatchNormalization()(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(L_2, 3, activation='relu', kernel_initializer='he_normal')(pool1)
    conv2 = Conv2D(L_2, 3, activation='relu', kernel_initializer='he_normal')(conv2)
    conv2 = BatchNormalization()(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(L_3, 3, activation='relu', kernel_initializer='he_normal')(pool2)
    conv3 = Conv2D(L_3, 3, activation='relu', kernel_initializer='he_normal')(conv3)
    conv3 = BatchNormalization()(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(L_4, 3, activation='relu', kernel_initializer='he_normal')(pool3)
    conv4 = Conv2D(L_4, 3, activation='relu', kernel_initializer='he_normal')(conv4)
    conv4 = BatchNormalization()(conv4)
    up5 = Conv2D(L_3, 2, activation='relu', kernel_initializer='he_normal')(
        UpSampling2D(size=(2, 2))(conv4))
    up5 = Conv2DTranspose(L_3,[1,2],activation='relu')(up5)
    up5 = tf.keras.layers.Resizing(121, 126, interpolation="bilinear", crop_to_aspect_ratio=False)(up5)

    merge5 = concatenate([conv3, up5], axis=3)
    conv5 = Conv2D(L_3, 3, activation='relu', kernel_initializer='he_normal')(merge5)
    conv5 = Conv2D(L_3, 3, activation='relu', kernel_initializer='he_normal')(conv5)
    conv5 = BatchNormalization()(conv5)
    up6 = Conv2D(L_2, 2, activation='relu', kernel_initializer='he_normal')(
        UpSampling2D(size=(2, 2))(conv5))
    up6 = Conv2DTranspose(L_2, [1, 2], activation='relu')(up6)
    up6 = tf.keras.layers.Resizing(250, 261, interpolation="bilinear", crop_to_aspect_ratio=False)(up6)
    merge6 = concatenate([conv2, up6], axis=3)
    conv6 = Conv2D(L_2, 3, activation='relu', kernel_initializer='he_normal')(merge6)
    conv6 = Conv2D(L_2, 3, activation='relu', kernel_initializer='he_normal')(conv6)
    conv6 = BatchNormalization()(conv6)
    up7 = Conv2D(L, 2, activation='relu', kernel_initializer='he_normal')(
        UpSampling2D(size=(2, 2))(conv6))
    up7 = Conv2DTranspose(L, [1, 2], activation='relu')(up7) #OFF PARA ARAD
    up7 = tf.keras.layers.Resizing(508, 531, interpolation="bilinear", crop_to_aspect_ratio=False)(up7)
    merge7 = concatenate([conv1, up7], axis=3)
    conv7 = Conv2D(L, 3, activation='relu', kernel_initializer='he_normal')(merge7)
    conv7 = Conv2D(L, 3, activation='relu', kernel_initializer='he_normal', )(conv7)
    conv7 = tf.keras.layers.Resizing(512, 535, interpolation="bilinear", crop_to_aspect_ratio=False)(conv7)
    final = Conv2D(1, 1)(conv7)


    model = Model(inputs, final)

    if (pretrained_weights):
        model.load_weights(pretrained_weights)

    return model

# %%
epochs =  1000# @param {type:"number"}

#-------------Net_model----------------------------------------------------------------
model = UNetL2(input_size=(IMG_HEIGHT,IMG_WIDTH,L_bands))
# model.summary()
model.compile(optimizer=optimizad, loss=loss,metrics = [PSNR_Metric])
history = model.fit(x=Y_inp,y=Y_oup, epochs=epochs)#, callbacks=[model_checkpoint_callback])
last_psnr=history.history['PSNR_Metric'][-1]
best_psnr=np.max(history.history['PSNR_Metric'])
iter_psnr=history.history['PSNR_Metric'].index(best_psnr)
best_loss=np.min(history.history['loss'])
iter_loss=history.history['loss'].index(best_loss)
name="Batch_no_padd" # @param {type:"string"}
name+=', '+str(best_psnr)+', '+str(best_loss)+', '+str(epochs)+'.h5'
print(name)
model.save(old_cp_dir+name)

#.------------ seee the accfuracy---------------
plt.plot(history.history['loss'], label='loss')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.show()
plt.plot(history.history['PSNR_Metric'], label='PSNR_Metric')
plt.xlabel('Epoch')
plt.ylabel('PSNR_Metric')
plt.show()

# %%
#@markdown UNet - Variance Scaling NO padd
def UNetL2(pretrained_weights=None, input_size=(256, 256, 12)):

    init = tf.keras.initializers.VarianceScaling(
      scale=1.0,
      mode='fan_in',
      distribution='truncated_normal',
      seed=None
    )

    inputs = Input(input_size)
    L = 16;
    L_2 = 2 * L;
    L_3 = 3 * L;
    L_4 = 4 * L;
    conv1 = Conv2D(L, 3, activation='relu', kernel_initializer=init)(inputs)
    conv1 = Conv2D(L, 3, activation='relu', kernel_initializer=init)(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(L_2, 3, activation='relu', kernel_initializer=init)(pool1)
    conv2 = Conv2D(L_2, 3, activation='relu', kernel_initializer=init)(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(L_3, 3, activation='relu', kernel_initializer=init)(pool2)
    conv3 = Conv2D(L_3, 3, activation='relu', kernel_initializer=init)(conv3)
    # drop3 = Dropout(0.5)(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(L_4, 3, activation='relu', kernel_initializer=init)(pool3)
    conv4 = Conv2D(L_4, 3, activation='relu', kernel_initializer=init)(conv4)
    # drop4 = Dropout(0.5)(conv4)

    up5 = Conv2D(L_3, 2, activation='relu', kernel_initializer=init)(
        UpSampling2D(size=(2, 2))(conv4))
    up5 = Conv2DTranspose(L_3,[1,2],activation='relu')(up5)
    up5 = tf.keras.layers.Resizing(121, 126, interpolation="bilinear", crop_to_aspect_ratio=False)(up5)

    merge5 = concatenate([conv3, up5], axis=3)
    conv5 = Conv2D(L_3, 3, activation='relu', kernel_initializer=init)(merge5)
    conv5 = Conv2D(L_3, 3, activation='relu', kernel_initializer=init)(conv5)

    up6 = Conv2D(L_2, 2, activation='relu', kernel_initializer=init)(
        UpSampling2D(size=(2, 2))(conv5))
    up6 = Conv2DTranspose(L_2, [1, 2], activation='relu')(up6)
    up6 = tf.keras.layers.Resizing(250, 261, interpolation="bilinear", crop_to_aspect_ratio=False)(up6)
    merge6 = concatenate([conv2, up6], axis=3)
    conv6 = Conv2D(L_2, 3, activation='relu', kernel_initializer=init)(merge6)
    conv6 = Conv2D(L_2, 3, activation='relu', kernel_initializer=init)(conv6)

    up7 = Conv2D(L, 2, activation='relu', kernel_initializer=init)(
        UpSampling2D(size=(2, 2))(conv6))
    up7 = Conv2DTranspose(L, [1, 2], activation='relu')(up7) #OFF PARA ARAD
    up7 = tf.keras.layers.Resizing(508, 531, interpolation="bilinear", crop_to_aspect_ratio=False)(up7)
    merge7 = concatenate([conv1, up7], axis=3)
    conv7 = Conv2D(L, 3, activation='relu', kernel_initializer=init)(merge7)
    conv7 = Conv2D(L, 3, activation='relu', kernel_initializer=init, )(conv7)
    conv7 = tf.keras.layers.Resizing(512, 535, interpolation="bilinear", crop_to_aspect_ratio=False)(conv7)
    final = Conv2D(1, 1)(conv7)


    model = Model(inputs, final)

    if (pretrained_weights):
        model.load_weights(pretrained_weights)

    return model

# %%
epochs =  1000# @param {type:"number"}

#-------------Net_model----------------------------------------------------------------
model = UNetL2(input_size=(IMG_HEIGHT,IMG_WIDTH,L_bands))
# model.summary()
model.compile(optimizer=optimizad, loss=loss,metrics = [PSNR_Metric])
history = model.fit(x=Y_inp,y=Y_oup, epochs=epochs)#, callbacks=[model_checkpoint_callback])
last_psnr=history.history['PSNR_Metric'][-1]
best_psnr=np.max(history.history['PSNR_Metric'])
iter_psnr=history.history['PSNR_Metric'].index(best_psnr)
best_loss=np.min(history.history['loss'])
iter_loss=history.history['loss'].index(best_loss)
name="VarianceScaling_NoPadd" # @param {type:"string"}
name+=', '+str(best_psnr)+', '+str(best_loss)+', '+str(epochs)+'.h5'
print(name)
model.save(old_cp_dir+name)

#.------------ seee the accfuracy---------------
plt.plot(history.history['loss'], label='loss')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.show()
plt.plot(history.history['PSNR_Metric'], label='PSNR_Metric')
plt.xlabel('Epoch')
plt.ylabel('PSNR_Metric')
plt.show()

# %%
#@markdown UNet - Variance Scaling - NO padd - Batch
def UNetL2(pretrained_weights=None, input_size=(256, 256, 12)):

    init = tf.keras.initializers.VarianceScaling(
      scale=1.0,
      mode='fan_in',
      distribution='truncated_normal',
      seed=None
    )

    inputs = Input(input_size)
    L = 16;
    L_2 = 2 * L;
    L_3 = 3 * L;
    L_4 = 4 * L;
    conv1 = Conv2D(L, 3, activation='relu', kernel_initializer=init)(inputs)
    conv1 = Conv2D(L, 3, activation='relu', kernel_initializer=init)(conv1)
    conv1 = BatchNormalization()(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(L_2, 3, activation='relu', kernel_initializer=init)(pool1)
    conv2 = Conv2D(L_2, 3, activation='relu', kernel_initializer=init)(conv2)
    conv2 = BatchNormalization()(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(L_3, 3, activation='relu', kernel_initializer=init)(pool2)
    conv3 = Conv2D(L_3, 3, activation='relu', kernel_initializer=init)(conv3)
    conv3 = BatchNormalization()(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(L_4, 3, activation='relu', kernel_initializer=init)(pool3)
    conv4 = Conv2D(L_4, 3, activation='relu', kernel_initializer=init)(conv4)
    conv4 = BatchNormalization()(conv4)
    up5 = Conv2D(L_3, 2, activation='relu', kernel_initializer=init)(
        UpSampling2D(size=(2, 2))(conv4))
    up5 = Conv2DTranspose(L_3,[1,2],activation='relu')(up5)
    up5 = tf.keras.layers.Resizing(121, 126, interpolation="bilinear", crop_to_aspect_ratio=False)(up5)

    merge5 = concatenate([conv3, up5], axis=3)
    conv5 = Conv2D(L_3, 3, activation='relu', kernel_initializer=init)(merge5)
    conv5 = Conv2D(L_3, 3, activation='relu', kernel_initializer=init)(conv5)
    conv5 = BatchNormalization()(conv5)
    up6 = Conv2D(L_2, 2, activation='relu', kernel_initializer=init)(
        UpSampling2D(size=(2, 2))(conv5))
    up6 = Conv2DTranspose(L_2, [1, 2], activation='relu')(up6)
    up6 = tf.keras.layers.Resizing(250, 261, interpolation="bilinear", crop_to_aspect_ratio=False)(up6)
    merge6 = concatenate([conv2, up6], axis=3)
    conv6 = Conv2D(L_2, 3, activation='relu', kernel_initializer=init)(merge6)
    conv6 = Conv2D(L_2, 3, activation='relu', kernel_initializer=init)(conv6)
    conv6 = BatchNormalization()(conv6)
    up7 = Conv2D(L, 2, activation='relu', kernel_initializer=init)(
        UpSampling2D(size=(2, 2))(conv6))
    up7 = Conv2DTranspose(L, [1, 2], activation='relu')(up7) #OFF PARA ARAD
    up7 = tf.keras.layers.Resizing(508, 531, interpolation="bilinear", crop_to_aspect_ratio=False)(up7)
    merge7 = concatenate([conv1, up7], axis=3)
    conv7 = Conv2D(L, 3, activation='relu', kernel_initializer=init)(merge7)
    conv7 = Conv2D(L, 3, activation='relu', kernel_initializer=init, )(conv7)
    conv7 = tf.keras.layers.Resizing(512, 535, interpolation="bilinear", crop_to_aspect_ratio=False)(conv7)
    final = Conv2D(1, 1)(conv7)


    model = Model(inputs, final)

    if (pretrained_weights):
        model.load_weights(pretrained_weights)

    return model

# %%
epochs =  1000# @param {type:"number"}

#-------------Net_model----------------------------------------------------------------
model = UNetL2(input_size=(IMG_HEIGHT,IMG_WIDTH,L_bands))
# model.summary()
model.compile(optimizer=optimizad, loss=loss,metrics = [PSNR_Metric])
history = model.fit(x=Y_inp,y=Y_oup, epochs=epochs)#, callbacks=[model_checkpoint_callback])
last_psnr=history.history['PSNR_Metric'][-1]
best_psnr=np.max(history.history['PSNR_Metric'])
iter_psnr=history.history['PSNR_Metric'].index(best_psnr)
best_loss=np.min(history.history['loss'])
iter_loss=history.history['loss'].index(best_loss)
name="VarianceScaling_NoPadd_Batch" # @param {type:"string"}
name+=', '+str(best_psnr)+', '+str(best_loss)+', '+str(epochs)+'.h5'
print(name)
model.save(old_cp_dir+name)

#.------------ seee the accfuracy---------------
plt.plot(history.history['loss'], label='loss')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.show()
plt.plot(history.history['PSNR_Metric'], label='PSNR_Metric')
plt.xlabel('Epoch')
plt.ylabel('PSNR_Metric')
plt.show()
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0623 - PSNR_Metric: 12.3303
# Epoch 2/1000
# 1/1 [==============================] - 1s 599ms/step - loss: 0.0332 - PSNR_Metric: 15.0377
# Epoch 3/1000
# 1/1 [==============================] - 1s 599ms/step - loss: 0.0221 - PSNR_Metric: 16.7793
# Epoch 4/1000
# 1/1 [==============================] - 1s 599ms/step - loss: 0.0184 - PSNR_Metric: 17.6030
# Epoch 5/1000
# 1/1 [==============================] - 1s 605ms/step - loss: 0.0121 - PSNR_Metric: 19.3969
# Epoch 6/1000
# 1/1 [==============================] - 1s 605ms/step - loss: 0.0090 - PSNR_Metric: 20.7160
# Epoch 7/1000
# 1/1 [==============================] - 1s 604ms/step - loss: 0.0077 - PSNR_Metric: 21.3942
# Epoch 8/1000
# 1/1 [==============================] - 1s 604ms/step - loss: 0.0068 - PSNR_Metric: 21.9329
# Epoch 9/1000
# 1/1 [==============================] - 1s 609ms/step - loss: 0.0061 - PSNR_Metric: 22.4770
# Epoch 10/1000
# 1/1 [==============================] - 1s 604ms/step - loss: 0.0055 - PSNR_Metric: 22.9017
# Epoch 11/1000
# 1/1 [==============================] - 1s 607ms/step - loss: 0.0051 - PSNR_Metric: 23.2537
# Epoch 12/1000
# 1/1 [==============================] - 1s 602ms/step - loss: 0.0047 - PSNR_Metric: 23.5533
# Epoch 13/1000
# 1/1 [==============================] - 1s 608ms/step - loss: 0.0044 - PSNR_Metric: 23.8303
# Epoch 14/1000
# 1/1 [==============================] - 1s 606ms/step - loss: 0.0042 - PSNR_Metric: 24.0675
# Epoch 15/1000
# 1/1 [==============================] - 1s 600ms/step - loss: 0.0040 - PSNR_Metric: 24.2914
# Epoch 16/1000
# 1/1 [==============================] - 1s 601ms/step - loss: 0.0038 - PSNR_Metric: 24.5375
# Epoch 17/1000
# 1/1 [==============================] - 1s 598ms/step - loss: 0.0036 - PSNR_Metric: 24.7497
# Epoch 18/1000
# 1/1 [==============================] - 1s 604ms/step - loss: 0.0035 - PSNR_Metric: 24.9246
# Epoch 19/1000
# 1/1 [==============================] - 1s 606ms/step - loss: 0.0034 - PSNR_Metric: 25.0712
# Epoch 20/1000
# 1/1 [==============================] - 1s 602ms/step - loss: 0.0033 - PSNR_Metric: 25.1920
# Epoch 21/1000
# 1/1 [==============================] - 1s 605ms/step - loss: 0.0032 - PSNR_Metric: 25.2825
# Epoch 22/1000
# 1/1 [==============================] - 1s 606ms/step - loss: 0.0031 - PSNR_Metric: 25.3501
# Epoch 23/1000
# 1/1 [==============================] - 1s 610ms/step - loss: 0.0031 - PSNR_Metric: 25.4180
# Epoch 24/1000
# 1/1 [==============================] - 1s 608ms/step - loss: 0.0030 - PSNR_Metric: 25.5044
# Epoch 25/1000
# 1/1 [==============================] - 1s 607ms/step - loss: 0.0030 - PSNR_Metric: 25.6042
# Epoch 26/1000
# 1/1 [==============================] - 1s 612ms/step - loss: 0.0029 - PSNR_Metric: 25.6975
# Epoch 27/1000
# 1/1 [==============================] - 1s 605ms/step - loss: 0.0029 - PSNR_Metric: 25.7688
# Epoch 28/1000
# 1/1 [==============================] - 1s 605ms/step - loss: 0.0028 - PSNR_Metric: 25.8183
# Epoch 29/1000
# 1/1 [==============================] - 1s 609ms/step - loss: 0.0028 - PSNR_Metric: 25.8610
# Epoch 30/1000
# 1/1 [==============================] - 1s 608ms/step - loss: 0.0028 - PSNR_Metric: 25.9102
# Epoch 31/1000
# 1/1 [==============================] - 1s 612ms/step - loss: 0.0027 - PSNR_Metric: 25.9616
# Epoch 32/1000
# 1/1 [==============================] - 1s 606ms/step - loss: 0.0027 - PSNR_Metric: 26.0018
# Epoch 33/1000
# 1/1 [==============================] - 1s 608ms/step - loss: 0.0027 - PSNR_Metric: 26.0310
# Epoch 34/1000
# 1/1 [==============================] - 1s 611ms/step - loss: 0.0027 - PSNR_Metric: 26.0658
# Epoch 35/1000
# 1/1 [==============================] - 1s 616ms/step - loss: 0.0026 - PSNR_Metric: 26.1105
# Epoch 36/1000
# 1/1 [==============================] - 1s 612ms/step - loss: 0.0026 - PSNR_Metric: 26.1550
# Epoch 37/1000
# 1/1 [==============================] - 1s 616ms/step - loss: 0.0026 - PSNR_Metric: 26.1940
# Epoch 38/1000
# 1/1 [==============================] - 1s 609ms/step - loss: 0.0026 - PSNR_Metric: 26.2297
# Epoch 39/1000
# 1/1 [==============================] - 1s 614ms/step - loss: 0.0026 - PSNR_Metric: 26.2657
# Epoch 40/1000
# 1/1 [==============================] - 1s 606ms/step - loss: 0.0025 - PSNR_Metric: 26.3016
# Epoch 41/1000
# 1/1 [==============================] - 1s 613ms/step - loss: 0.0025 - PSNR_Metric: 26.3338
# Epoch 42/1000
# 1/1 [==============================] - 1s 608ms/step - loss: 0.0025 - PSNR_Metric: 26.3608
# Epoch 43/1000
# 1/1 [==============================] - 1s 613ms/step - loss: 0.0025 - PSNR_Metric: 26.3860
# Epoch 44/1000
# 1/1 [==============================] - 1s 609ms/step - loss: 0.0025 - PSNR_Metric: 26.4140
# Epoch 45/1000
# 1/1 [==============================] - 1s 616ms/step - loss: 0.0025 - PSNR_Metric: 26.4456
# Epoch 46/1000
# 1/1 [==============================] - 1s 615ms/step - loss: 0.0024 - PSNR_Metric: 26.4775
# Epoch 47/1000
# 1/1 [==============================] - 1s 615ms/step - loss: 0.0024 - PSNR_Metric: 26.5058
# Epoch 48/1000
# 1/1 [==============================] - 1s 619ms/step - loss: 0.0024 - PSNR_Metric: 26.5303
# Epoch 49/1000
# 1/1 [==============================] - 1s 634ms/step - loss: 0.0024 - PSNR_Metric: 26.5526
# Epoch 50/1000
# 1/1 [==============================] - 1s 618ms/step - loss: 0.0024 - PSNR_Metric: 26.5734
# Epoch 51/1000
# 1/1 [==============================] - 1s 634ms/step - loss: 0.0024 - PSNR_Metric: 26.5921
# Epoch 52/1000
# 1/1 [==============================] - 1s 619ms/step - loss: 0.0024 - PSNR_Metric: 26.6083
# Epoch 53/1000
# 1/1 [==============================] - 1s 618ms/step - loss: 0.0024 - PSNR_Metric: 26.6240
# Epoch 54/1000
# 1/1 [==============================] - 1s 616ms/step - loss: 0.0024 - PSNR_Metric: 26.6414
# Epoch 55/1000
# 1/1 [==============================] - 1s 614ms/step - loss: 0.0023 - PSNR_Metric: 26.6609
# Epoch 56/1000
# 1/1 [==============================] - 1s 621ms/step - loss: 0.0023 - PSNR_Metric: 26.6808
# Epoch 57/1000
# 1/1 [==============================] - 1s 609ms/step - loss: 0.0023 - PSNR_Metric: 26.6995
# Epoch 58/1000
# 1/1 [==============================] - 1s 619ms/step - loss: 0.0023 - PSNR_Metric: 26.7169
# Epoch 59/1000
# 1/1 [==============================] - 1s 619ms/step - loss: 0.0023 - PSNR_Metric: 26.7333
# Epoch 60/1000
# 1/1 [==============================] - 1s 618ms/step - loss: 0.0023 - PSNR_Metric: 26.7484
# Epoch 61/1000
# 1/1 [==============================] - 1s 620ms/step - loss: 0.0023 - PSNR_Metric: 26.7622
# Epoch 62/1000
# 1/1 [==============================] - 1s 624ms/step - loss: 0.0023 - PSNR_Metric: 26.7754
# Epoch 63/1000
# 1/1 [==============================] - 1s 625ms/step - loss: 0.0023 - PSNR_Metric: 26.7891
# Epoch 64/1000
# 1/1 [==============================] - 1s 623ms/step - loss: 0.0023 - PSNR_Metric: 26.8038
# Epoch 65/1000
# 1/1 [==============================] - 1s 621ms/step - loss: 0.0023 - PSNR_Metric: 26.8190
# Epoch 66/1000
# 1/1 [==============================] - 1s 622ms/step - loss: 0.0023 - PSNR_Metric: 26.8338
# Epoch 67/1000
# 1/1 [==============================] - 1s 620ms/step - loss: 0.0023 - PSNR_Metric: 26.8477
# Epoch 68/1000
# 1/1 [==============================] - 1s 631ms/step - loss: 0.0023 - PSNR_Metric: 26.8609
# Epoch 69/1000
# 1/1 [==============================] - 1s 626ms/step - loss: 0.0022 - PSNR_Metric: 26.8735
# Epoch 70/1000
# 1/1 [==============================] - 1s 621ms/step - loss: 0.0022 - PSNR_Metric: 26.8853
# Epoch 71/1000
# 1/1 [==============================] - 1s 624ms/step - loss: 0.0022 - PSNR_Metric: 26.8968
# Epoch 72/1000
# 1/1 [==============================] - 1s 621ms/step - loss: 0.0022 - PSNR_Metric: 26.9084
# Epoch 73/1000
# 1/1 [==============================] - 1s 622ms/step - loss: 0.0022 - PSNR_Metric: 26.9208
# Epoch 74/1000
# 1/1 [==============================] - 1s 621ms/step - loss: 0.0022 - PSNR_Metric: 26.9337
# Epoch 75/1000
# 1/1 [==============================] - 1s 626ms/step - loss: 0.0022 - PSNR_Metric: 26.9466
# Epoch 76/1000
# 1/1 [==============================] - 1s 622ms/step - loss: 0.0022 - PSNR_Metric: 26.9590
# Epoch 77/1000
# 1/1 [==============================] - 1s 627ms/step - loss: 0.0022 - PSNR_Metric: 26.9709
# Epoch 78/1000
# 1/1 [==============================] - 1s 623ms/step - loss: 0.0022 - PSNR_Metric: 26.9823
# Epoch 79/1000
# 1/1 [==============================] - 1s 623ms/step - loss: 0.0022 - PSNR_Metric: 26.9932
# Epoch 80/1000
# 1/1 [==============================] - 1s 628ms/step - loss: 0.0022 - PSNR_Metric: 27.0041
# Epoch 81/1000
# 1/1 [==============================] - 1s 626ms/step - loss: 0.0022 - PSNR_Metric: 27.0153
# Epoch 82/1000
# 1/1 [==============================] - 1s 625ms/step - loss: 0.0022 - PSNR_Metric: 27.0270
# Epoch 83/1000
# 1/1 [==============================] - 1s 626ms/step - loss: 0.0022 - PSNR_Metric: 27.0390
# Epoch 84/1000
# 1/1 [==============================] - 1s 627ms/step - loss: 0.0022 - PSNR_Metric: 27.0509
# Epoch 85/1000
# 1/1 [==============================] - 1s 636ms/step - loss: 0.0022 - PSNR_Metric: 27.0624
# Epoch 86/1000
# 1/1 [==============================] - 1s 626ms/step - loss: 0.0022 - PSNR_Metric: 27.0734
# Epoch 87/1000
# 1/1 [==============================] - 1s 629ms/step - loss: 0.0021 - PSNR_Metric: 27.0839
# Epoch 88/1000
# 1/1 [==============================] - 1s 632ms/step - loss: 0.0021 - PSNR_Metric: 27.0942
# Epoch 89/1000
# 1/1 [==============================] - 1s 628ms/step - loss: 0.0021 - PSNR_Metric: 27.1047
# Epoch 90/1000
# 1/1 [==============================] - 1s 630ms/step - loss: 0.0021 - PSNR_Metric: 27.1155
# Epoch 91/1000
# 1/1 [==============================] - 1s 631ms/step - loss: 0.0021 - PSNR_Metric: 27.1266
# Epoch 92/1000
# 1/1 [==============================] - 1s 633ms/step - loss: 0.0021 - PSNR_Metric: 27.1375
# Epoch 93/1000
# 1/1 [==============================] - 1s 629ms/step - loss: 0.0021 - PSNR_Metric: 27.1481
# Epoch 94/1000
# 1/1 [==============================] - 1s 636ms/step - loss: 0.0021 - PSNR_Metric: 27.1581
# Epoch 95/1000
# 1/1 [==============================] - 1s 635ms/step - loss: 0.0021 - PSNR_Metric: 27.1678
# Epoch 96/1000
# 1/1 [==============================] - 1s 634ms/step - loss: 0.0021 - PSNR_Metric: 27.1772
# Epoch 97/1000
# 1/1 [==============================] - 1s 631ms/step - loss: 0.0021 - PSNR_Metric: 27.1869
# Epoch 98/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0021 - PSNR_Metric: 27.1967
# Epoch 99/1000
# 1/1 [==============================] - 1s 632ms/step - loss: 0.0021 - PSNR_Metric: 27.2065
# Epoch 100/1000
# 1/1 [==============================] - 1s 635ms/step - loss: 0.0021 - PSNR_Metric: 27.2158
# Epoch 101/1000
# 1/1 [==============================] - 1s 631ms/step - loss: 0.0021 - PSNR_Metric: 27.2247
# Epoch 102/1000
# 1/1 [==============================] - 1s 635ms/step - loss: 0.0021 - PSNR_Metric: 27.2333
# Epoch 103/1000
# 1/1 [==============================] - 1s 634ms/step - loss: 0.0021 - PSNR_Metric: 27.2418
# Epoch 104/1000
# 1/1 [==============================] - 1s 631ms/step - loss: 0.0021 - PSNR_Metric: 27.2505
# Epoch 105/1000
# 1/1 [==============================] - 1s 635ms/step - loss: 0.0021 - PSNR_Metric: 27.2592
# Epoch 106/1000
# 1/1 [==============================] - 1s 634ms/step - loss: 0.0021 - PSNR_Metric: 27.2676
# Epoch 107/1000
# 1/1 [==============================] - 1s 635ms/step - loss: 0.0021 - PSNR_Metric: 27.2756
# Epoch 108/1000
# 1/1 [==============================] - 1s 636ms/step - loss: 0.0021 - PSNR_Metric: 27.2833
# Epoch 109/1000
# 1/1 [==============================] - 1s 643ms/step - loss: 0.0021 - PSNR_Metric: 27.2908
# Epoch 110/1000
# 1/1 [==============================] - 1s 643ms/step - loss: 0.0021 - PSNR_Metric: 27.2984
# Epoch 111/1000
# 1/1 [==============================] - 1s 636ms/step - loss: 0.0020 - PSNR_Metric: 27.3060
# Epoch 112/1000
# 1/1 [==============================] - 1s 633ms/step - loss: 0.0020 - PSNR_Metric: 27.3136
# Epoch 113/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0020 - PSNR_Metric: 27.3209
# Epoch 114/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0020 - PSNR_Metric: 27.3279
# Epoch 115/1000
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0020 - PSNR_Metric: 27.3348
# Epoch 116/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0020 - PSNR_Metric: 27.3418
# Epoch 117/1000
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0020 - PSNR_Metric: 27.3489
# Epoch 118/1000
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0020 - PSNR_Metric: 27.3559
# Epoch 119/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0020 - PSNR_Metric: 27.3627
# Epoch 120/1000
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0020 - PSNR_Metric: 27.3693
# Epoch 121/1000
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0020 - PSNR_Metric: 27.3758
# Epoch 122/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0020 - PSNR_Metric: 27.3823
# Epoch 123/1000
# 1/1 [==============================] - 1s 643ms/step - loss: 0.0020 - PSNR_Metric: 27.3887
# Epoch 124/1000
# 1/1 [==============================] - 1s 642ms/step - loss: 0.0020 - PSNR_Metric: 27.3950
# Epoch 125/1000
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0020 - PSNR_Metric: 27.4012
# Epoch 126/1000
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0020 - PSNR_Metric: 27.4072
# Epoch 127/1000
# 1/1 [==============================] - 1s 642ms/step - loss: 0.0020 - PSNR_Metric: 27.4132
# Epoch 128/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0020 - PSNR_Metric: 27.4192
# Epoch 129/1000
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0020 - PSNR_Metric: 27.4252
# Epoch 130/1000
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0020 - PSNR_Metric: 27.4310
# Epoch 131/1000
# 1/1 [==============================] - 1s 655ms/step - loss: 0.0020 - PSNR_Metric: 27.4368
# Epoch 132/1000
# 1/1 [==============================] - 1s 652ms/step - loss: 0.0020 - PSNR_Metric: 27.4426
# Epoch 133/1000
# 1/1 [==============================] - 1s 651ms/step - loss: 0.0020 - PSNR_Metric: 27.4482
# Epoch 134/1000
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0020 - PSNR_Metric: 27.4539
# Epoch 135/1000
# 1/1 [==============================] - 1s 648ms/step - loss: 0.0020 - PSNR_Metric: 27.4595
# Epoch 136/1000
# 1/1 [==============================] - 1s 651ms/step - loss: 0.0020 - PSNR_Metric: 27.4651
# Epoch 137/1000
# 1/1 [==============================] - 1s 643ms/step - loss: 0.0020 - PSNR_Metric: 27.4706
# Epoch 138/1000
# 1/1 [==============================] - 1s 648ms/step - loss: 0.0020 - PSNR_Metric: 27.4761
# Epoch 139/1000
# 1/1 [==============================] - 1s 645ms/step - loss: 0.0020 - PSNR_Metric: 27.4815
# Epoch 140/1000
# 1/1 [==============================] - 1s 649ms/step - loss: 0.0020 - PSNR_Metric: 27.4868
# Epoch 141/1000
# 1/1 [==============================] - 1s 651ms/step - loss: 0.0020 - PSNR_Metric: 27.4921
# Epoch 142/1000
# 1/1 [==============================] - 1s 650ms/step - loss: 0.0020 - PSNR_Metric: 27.4974
# Epoch 143/1000
# 1/1 [==============================] - 1s 652ms/step - loss: 0.0020 - PSNR_Metric: 27.5027
# Epoch 144/1000
# 1/1 [==============================] - 1s 638ms/step - loss: 0.0020 - PSNR_Metric: 27.5078
# Epoch 145/1000
# 1/1 [==============================] - 1s 657ms/step - loss: 0.0020 - PSNR_Metric: 27.5129
# Epoch 146/1000
# 1/1 [==============================] - 1s 650ms/step - loss: 0.0020 - PSNR_Metric: 27.5179
# Epoch 147/1000
# 1/1 [==============================] - 1s 652ms/step - loss: 0.0020 - PSNR_Metric: 27.5228
# Epoch 148/1000
# 1/1 [==============================] - 1s 647ms/step - loss: 0.0020 - PSNR_Metric: 27.5278
# Epoch 149/1000
# 1/1 [==============================] - 1s 646ms/step - loss: 0.0019 - PSNR_Metric: 27.5327
# Epoch 150/1000
# 1/1 [==============================] - 1s 647ms/step - loss: 0.0019 - PSNR_Metric: 27.5375
# Epoch 151/1000
# 1/1 [==============================] - 1s 650ms/step - loss: 0.0019 - PSNR_Metric: 27.5422
# Epoch 152/1000
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0019 - PSNR_Metric: 27.5469
# Epoch 153/1000
# 1/1 [==============================] - 1s 647ms/step - loss: 0.0019 - PSNR_Metric: 27.5516
# Epoch 154/1000
# 1/1 [==============================] - 1s 649ms/step - loss: 0.0019 - PSNR_Metric: 27.5563
# Epoch 155/1000
# 1/1 [==============================] - 1s 656ms/step - loss: 0.0019 - PSNR_Metric: 27.5608
# Epoch 156/1000
# 1/1 [==============================] - 1s 651ms/step - loss: 0.0019 - PSNR_Metric: 27.5652
# Epoch 157/1000
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0019 - PSNR_Metric: 27.5696
# Epoch 158/1000
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0019 - PSNR_Metric: 27.5741
# Epoch 159/1000
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0019 - PSNR_Metric: 27.5786
# Epoch 160/1000
# 1/1 [==============================] - 1s 643ms/step - loss: 0.0019 - PSNR_Metric: 27.5829
# Epoch 161/1000
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0019 - PSNR_Metric: 27.5872
# Epoch 162/1000
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0019 - PSNR_Metric: 27.5914
# Epoch 163/1000
# 1/1 [==============================] - 1s 647ms/step - loss: 0.0019 - PSNR_Metric: 27.5958
# Epoch 164/1000
# 1/1 [==============================] - 1s 643ms/step - loss: 0.0019 - PSNR_Metric: 27.6001
# Epoch 165/1000
# 1/1 [==============================] - 1s 643ms/step - loss: 0.0019 - PSNR_Metric: 27.6043
# Epoch 166/1000
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0019 - PSNR_Metric: 27.6084
# Epoch 167/1000
# 1/1 [==============================] - 1s 643ms/step - loss: 0.0019 - PSNR_Metric: 27.6125
# Epoch 168/1000
# 1/1 [==============================] - 1s 647ms/step - loss: 0.0019 - PSNR_Metric: 27.6167
# Epoch 169/1000
# 1/1 [==============================] - 1s 660ms/step - loss: 0.0019 - PSNR_Metric: 27.6208
# Epoch 170/1000
# 1/1 [==============================] - 1s 652ms/step - loss: 0.0019 - PSNR_Metric: 27.6248
# Epoch 171/1000
# 1/1 [==============================] - 1s 654ms/step - loss: 0.0019 - PSNR_Metric: 27.6287
# Epoch 172/1000
# 1/1 [==============================] - 1s 653ms/step - loss: 0.0019 - PSNR_Metric: 27.6328
# Epoch 173/1000
# 1/1 [==============================] - 1s 657ms/step - loss: 0.0019 - PSNR_Metric: 27.6368
# Epoch 174/1000
# 1/1 [==============================] - 1s 655ms/step - loss: 0.0019 - PSNR_Metric: 27.6407
# Epoch 175/1000
# 1/1 [==============================] - 1s 650ms/step - loss: 0.0019 - PSNR_Metric: 27.6445
# Epoch 176/1000
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0019 - PSNR_Metric: 27.6483
# Epoch 177/1000
# 1/1 [==============================] - 1s 637ms/step - loss: 0.0019 - PSNR_Metric: 27.6521
# Epoch 178/1000
# 1/1 [==============================] - 1s 633ms/step - loss: 0.0019 - PSNR_Metric: 27.6560
# Epoch 179/1000
# 1/1 [==============================] - 1s 642ms/step - loss: 0.0019 - PSNR_Metric: 27.6599
# Epoch 180/1000
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0019 - PSNR_Metric: 27.6637
# Epoch 181/1000
# 1/1 [==============================] - 1s 638ms/step - loss: 0.0019 - PSNR_Metric: 27.6674
# Epoch 182/1000
# 1/1 [==============================] - 1s 643ms/step - loss: 0.0019 - PSNR_Metric: 27.6711
# Epoch 183/1000
# 1/1 [==============================] - 1s 635ms/step - loss: 0.0019 - PSNR_Metric: 27.6749
# Epoch 184/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0019 - PSNR_Metric: 27.6787
# Epoch 185/1000
# 1/1 [==============================] - 1s 636ms/step - loss: 0.0019 - PSNR_Metric: 27.6822
# Epoch 186/1000
# 1/1 [==============================] - 1s 633ms/step - loss: 0.0019 - PSNR_Metric: 27.6857
# Epoch 187/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0019 - PSNR_Metric: 27.6892
# Epoch 188/1000
# 1/1 [==============================] - 1s 634ms/step - loss: 0.0019 - PSNR_Metric: 27.6928
# Epoch 189/1000
# 1/1 [==============================] - 1s 643ms/step - loss: 0.0019 - PSNR_Metric: 27.6963
# Epoch 190/1000
# 1/1 [==============================] - 1s 637ms/step - loss: 0.0019 - PSNR_Metric: 27.6996
# Epoch 191/1000
# 1/1 [==============================] - 1s 637ms/step - loss: 0.0019 - PSNR_Metric: 27.7030
# Epoch 192/1000
# 1/1 [==============================] - 1s 636ms/step - loss: 0.0019 - PSNR_Metric: 27.7064
# Epoch 193/1000
# 1/1 [==============================] - 1s 635ms/step - loss: 0.0019 - PSNR_Metric: 27.7099
# Epoch 194/1000
# 1/1 [==============================] - 1s 638ms/step - loss: 0.0019 - PSNR_Metric: 27.7133
# Epoch 195/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0019 - PSNR_Metric: 27.7165
# Epoch 196/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0019 - PSNR_Metric: 27.7198
# Epoch 197/1000
# 1/1 [==============================] - 1s 636ms/step - loss: 0.0019 - PSNR_Metric: 27.7232
# Epoch 198/1000
# 1/1 [==============================] - 1s 636ms/step - loss: 0.0019 - PSNR_Metric: 27.7266
# Epoch 199/1000
# 1/1 [==============================] - 1s 649ms/step - loss: 0.0019 - PSNR_Metric: 27.7299
# Epoch 200/1000
# 1/1 [==============================] - 1s 649ms/step - loss: 0.0019 - PSNR_Metric: 27.7330
# Epoch 201/1000
# 1/1 [==============================] - 1s 647ms/step - loss: 0.0019 - PSNR_Metric: 27.7362
# Epoch 202/1000
# 1/1 [==============================] - 1s 636ms/step - loss: 0.0019 - PSNR_Metric: 27.7396
# Epoch 203/1000
# 1/1 [==============================] - 1s 637ms/step - loss: 0.0019 - PSNR_Metric: 27.7428
# Epoch 204/1000
# 1/1 [==============================] - 1s 638ms/step - loss: 0.0019 - PSNR_Metric: 27.7459
# Epoch 205/1000
# 1/1 [==============================] - 1s 638ms/step - loss: 0.0019 - PSNR_Metric: 27.7489
# Epoch 206/1000
# 1/1 [==============================] - 1s 642ms/step - loss: 0.0019 - PSNR_Metric: 27.7520
# Epoch 207/1000
# 1/1 [==============================] - 1s 635ms/step - loss: 0.0019 - PSNR_Metric: 27.7553
# Epoch 208/1000
# 1/1 [==============================] - 1s 631ms/step - loss: 0.0019 - PSNR_Metric: 27.7584
# Epoch 209/1000
# 1/1 [==============================] - 1s 638ms/step - loss: 0.0019 - PSNR_Metric: 27.7614
# Epoch 210/1000
# 1/1 [==============================] - 1s 634ms/step - loss: 0.0019 - PSNR_Metric: 27.7644
# Epoch 211/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0019 - PSNR_Metric: 27.7675
# Epoch 212/1000
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0018 - PSNR_Metric: 27.7707
# Epoch 213/1000
# 1/1 [==============================] - 1s 637ms/step - loss: 0.0018 - PSNR_Metric: 27.7737
# Epoch 214/1000
# 1/1 [==============================] - 1s 638ms/step - loss: 0.0018 - PSNR_Metric: 27.7765
# Epoch 215/1000
# 1/1 [==============================] - 1s 636ms/step - loss: 0.0018 - PSNR_Metric: 27.7794
# Epoch 216/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0018 - PSNR_Metric: 27.7824
# Epoch 217/1000
# 1/1 [==============================] - 1s 638ms/step - loss: 0.0018 - PSNR_Metric: 27.7854
# Epoch 218/1000
# 1/1 [==============================] - 1s 637ms/step - loss: 0.0018 - PSNR_Metric: 27.7882
# Epoch 219/1000
# 1/1 [==============================] - 1s 643ms/step - loss: 0.0018 - PSNR_Metric: 27.7910
# Epoch 220/1000
# 1/1 [==============================] - 1s 646ms/step - loss: 0.0018 - PSNR_Metric: 27.7938
# Epoch 221/1000
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0018 - PSNR_Metric: 27.7967
# Epoch 222/1000
# 1/1 [==============================] - 1s 643ms/step - loss: 0.0018 - PSNR_Metric: 27.7996
# Epoch 223/1000
# 1/1 [==============================] - 1s 650ms/step - loss: 0.0018 - PSNR_Metric: 27.8024
# Epoch 224/1000
# 1/1 [==============================] - 1s 645ms/step - loss: 0.0018 - PSNR_Metric: 27.8051
# Epoch 225/1000
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0018 - PSNR_Metric: 27.8080
# Epoch 226/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0018 - PSNR_Metric: 27.8109
# Epoch 227/1000
# 1/1 [==============================] - 1s 634ms/step - loss: 0.0018 - PSNR_Metric: 27.8137
# Epoch 228/1000
# 1/1 [==============================] - 1s 645ms/step - loss: 0.0018 - PSNR_Metric: 27.8165
# Epoch 229/1000
# 1/1 [==============================] - 1s 635ms/step - loss: 0.0018 - PSNR_Metric: 27.8193
# Epoch 230/1000
# 1/1 [==============================] - 1s 634ms/step - loss: 0.0018 - PSNR_Metric: 27.8220
# Epoch 231/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0018 - PSNR_Metric: 27.8248
# Epoch 232/1000
# 1/1 [==============================] - 1s 635ms/step - loss: 0.0018 - PSNR_Metric: 27.8275
# Epoch 233/1000
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0018 - PSNR_Metric: 27.8301
# Epoch 234/1000
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0018 - PSNR_Metric: 27.8328
# Epoch 235/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0018 - PSNR_Metric: 27.8354
# Epoch 236/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0018 - PSNR_Metric: 27.8381
# Epoch 237/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0018 - PSNR_Metric: 27.8407
# Epoch 238/1000
# 1/1 [==============================] - 1s 638ms/step - loss: 0.0018 - PSNR_Metric: 27.8433
# Epoch 239/1000
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0018 - PSNR_Metric: 27.8459
# Epoch 240/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0018 - PSNR_Metric: 27.8486
# Epoch 241/1000
# 1/1 [==============================] - 1s 638ms/step - loss: 0.0018 - PSNR_Metric: 27.8511
# Epoch 242/1000
# 1/1 [==============================] - 1s 638ms/step - loss: 0.0018 - PSNR_Metric: 27.8537
# Epoch 243/1000
# 1/1 [==============================] - 1s 635ms/step - loss: 0.0018 - PSNR_Metric: 27.8562
# Epoch 244/1000
# 1/1 [==============================] - 1s 637ms/step - loss: 0.0018 - PSNR_Metric: 27.8588
# Epoch 245/1000
# 1/1 [==============================] - 1s 637ms/step - loss: 0.0018 - PSNR_Metric: 27.8614
# Epoch 246/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0018 - PSNR_Metric: 27.8638
# Epoch 247/1000
# 1/1 [==============================] - 1s 645ms/step - loss: 0.0018 - PSNR_Metric: 27.8663
# Epoch 248/1000
# 1/1 [==============================] - 1s 636ms/step - loss: 0.0018 - PSNR_Metric: 27.8688
# Epoch 249/1000
# 1/1 [==============================] - 1s 636ms/step - loss: 0.0018 - PSNR_Metric: 27.8713
# Epoch 250/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0018 - PSNR_Metric: 27.8737
# Epoch 251/1000
# 1/1 [==============================] - 1s 638ms/step - loss: 0.0018 - PSNR_Metric: 27.8761
# Epoch 252/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0018 - PSNR_Metric: 27.8786
# Epoch 253/1000
# 1/1 [==============================] - 1s 634ms/step - loss: 0.0018 - PSNR_Metric: 27.8811
# Epoch 254/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0018 - PSNR_Metric: 27.8836
# Epoch 255/1000
# 1/1 [==============================] - 1s 642ms/step - loss: 0.0018 - PSNR_Metric: 27.8859
# Epoch 256/1000
# 1/1 [==============================] - 1s 635ms/step - loss: 0.0018 - PSNR_Metric: 27.8883
# Epoch 257/1000
# 1/1 [==============================] - 1s 636ms/step - loss: 0.0018 - PSNR_Metric: 27.8907
# Epoch 258/1000
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0018 - PSNR_Metric: 27.8931
# Epoch 259/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0018 - PSNR_Metric: 27.8954
# Epoch 260/1000
# 1/1 [==============================] - 1s 636ms/step - loss: 0.0018 - PSNR_Metric: 27.8977
# Epoch 261/1000
# 1/1 [==============================] - 1s 642ms/step - loss: 0.0018 - PSNR_Metric: 27.9000
# Epoch 262/1000
# 1/1 [==============================] - 1s 637ms/step - loss: 0.0018 - PSNR_Metric: 27.9024
# Epoch 263/1000
# 1/1 [==============================] - 1s 642ms/step - loss: 0.0018 - PSNR_Metric: 27.9047
# Epoch 264/1000
# 1/1 [==============================] - 1s 646ms/step - loss: 0.0018 - PSNR_Metric: 27.9070
# Epoch 265/1000
# 1/1 [==============================] - 1s 645ms/step - loss: 0.0018 - PSNR_Metric: 27.9093
# Epoch 266/1000
# 1/1 [==============================] - 1s 638ms/step - loss: 0.0018 - PSNR_Metric: 27.9116
# Epoch 267/1000
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0018 - PSNR_Metric: 27.9139
# Epoch 268/1000
# 1/1 [==============================] - 1s 638ms/step - loss: 0.0018 - PSNR_Metric: 27.9161
# Epoch 269/1000
# 1/1 [==============================] - 1s 646ms/step - loss: 0.0018 - PSNR_Metric: 27.9184
# Epoch 270/1000
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0018 - PSNR_Metric: 27.9207
# Epoch 271/1000
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0018 - PSNR_Metric: 27.9230
# Epoch 272/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0018 - PSNR_Metric: 27.9252
# Epoch 273/1000
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0018 - PSNR_Metric: 27.9275
# Epoch 274/1000
# 1/1 [==============================] - 1s 642ms/step - loss: 0.0018 - PSNR_Metric: 27.9298
# Epoch 275/1000
# 1/1 [==============================] - 1s 645ms/step - loss: 0.0018 - PSNR_Metric: 27.9320
# Epoch 276/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0018 - PSNR_Metric: 27.9342
# Epoch 277/1000
# 1/1 [==============================] - 1s 648ms/step - loss: 0.0018 - PSNR_Metric: 27.9363
# Epoch 278/1000
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0018 - PSNR_Metric: 27.9386
# Epoch 279/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0018 - PSNR_Metric: 27.9408
# Epoch 280/1000
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0018 - PSNR_Metric: 27.9429
# Epoch 281/1000
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0018 - PSNR_Metric: 27.9451
# Epoch 282/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0018 - PSNR_Metric: 27.9472
# Epoch 283/1000
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0018 - PSNR_Metric: 27.9493
# Epoch 284/1000
# 1/1 [==============================] - 1s 646ms/step - loss: 0.0018 - PSNR_Metric: 27.9514
# Epoch 285/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0018 - PSNR_Metric: 27.9535
# Epoch 286/1000
# 1/1 [==============================] - 1s 643ms/step - loss: 0.0018 - PSNR_Metric: 27.9556
# Epoch 287/1000
# 1/1 [==============================] - 1s 642ms/step - loss: 0.0018 - PSNR_Metric: 27.9577
# Epoch 288/1000
# 1/1 [==============================] - 1s 648ms/step - loss: 0.0018 - PSNR_Metric: 27.9599
# Epoch 289/1000
# 1/1 [==============================] - 1s 650ms/step - loss: 0.0018 - PSNR_Metric: 27.9621
# Epoch 290/1000
# 1/1 [==============================] - 1s 645ms/step - loss: 0.0018 - PSNR_Metric: 27.9643
# Epoch 291/1000
# 1/1 [==============================] - 1s 638ms/step - loss: 0.0018 - PSNR_Metric: 27.9664
# Epoch 292/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0018 - PSNR_Metric: 27.9685
# Epoch 293/1000
# 1/1 [==============================] - 1s 637ms/step - loss: 0.0018 - PSNR_Metric: 27.9707
# Epoch 294/1000
# 1/1 [==============================] - 1s 638ms/step - loss: 0.0018 - PSNR_Metric: 27.9729
# Epoch 295/1000
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0018 - PSNR_Metric: 27.9749
# Epoch 296/1000
# 1/1 [==============================] - 1s 636ms/step - loss: 0.0018 - PSNR_Metric: 27.9770
# Epoch 297/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0018 - PSNR_Metric: 27.9790
# Epoch 298/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0018 - PSNR_Metric: 27.9812
# Epoch 299/1000
# 1/1 [==============================] - 1s 643ms/step - loss: 0.0018 - PSNR_Metric: 27.9833
# Epoch 300/1000
# 1/1 [==============================] - 1s 647ms/step - loss: 0.0018 - PSNR_Metric: 27.9853
# Epoch 301/1000
# 1/1 [==============================] - 1s 643ms/step - loss: 0.0018 - PSNR_Metric: 27.9873
# Epoch 302/1000
# 1/1 [==============================] - 1s 645ms/step - loss: 0.0018 - PSNR_Metric: 27.9895
# Epoch 303/1000
# 1/1 [==============================] - 1s 646ms/step - loss: 0.0018 - PSNR_Metric: 27.9916
# Epoch 304/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0018 - PSNR_Metric: 27.9936
# Epoch 305/1000
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0018 - PSNR_Metric: 27.9957
# Epoch 306/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0018 - PSNR_Metric: 27.9978
# Epoch 307/1000
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0018 - PSNR_Metric: 27.9998
# Epoch 308/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0018 - PSNR_Metric: 28.0018
# Epoch 309/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0018 - PSNR_Metric: 28.0038
# Epoch 310/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0018 - PSNR_Metric: 28.0059
# Epoch 311/1000
# 1/1 [==============================] - 1s 652ms/step - loss: 0.0018 - PSNR_Metric: 28.0080
# Epoch 312/1000
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0018 - PSNR_Metric: 28.0100
# Epoch 313/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0018 - PSNR_Metric: 28.0120
# Epoch 314/1000
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0018 - PSNR_Metric: 28.0140
# Epoch 315/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0018 - PSNR_Metric: 28.0161
# Epoch 316/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0018 - PSNR_Metric: 28.0181
# Epoch 317/1000
# 1/1 [==============================] - 1s 638ms/step - loss: 0.0018 - PSNR_Metric: 28.0200
# Epoch 318/1000
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0017 - PSNR_Metric: 28.0221
# Epoch 319/1000
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0017 - PSNR_Metric: 28.0242
# Epoch 320/1000
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0017 - PSNR_Metric: 28.0262
# Epoch 321/1000
# 1/1 [==============================] - 1s 635ms/step - loss: 0.0017 - PSNR_Metric: 28.0281
# Epoch 322/1000
# 1/1 [==============================] - 1s 649ms/step - loss: 0.0017 - PSNR_Metric: 28.0301
# Epoch 323/1000
# 1/1 [==============================] - 1s 647ms/step - loss: 0.0017 - PSNR_Metric: 28.0321
# Epoch 324/1000
# 1/1 [==============================] - 1s 645ms/step - loss: 0.0017 - PSNR_Metric: 28.0340
# Epoch 325/1000
# 1/1 [==============================] - 1s 645ms/step - loss: 0.0017 - PSNR_Metric: 28.0359
# Epoch 326/1000
# 1/1 [==============================] - 1s 645ms/step - loss: 0.0017 - PSNR_Metric: 28.0379
# Epoch 327/1000
# 1/1 [==============================] - 1s 637ms/step - loss: 0.0017 - PSNR_Metric: 28.0399
# Epoch 328/1000
# 1/1 [==============================] - 1s 643ms/step - loss: 0.0017 - PSNR_Metric: 28.0418
# Epoch 329/1000
# 1/1 [==============================] - 1s 642ms/step - loss: 0.0017 - PSNR_Metric: 28.0437
# Epoch 330/1000
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0017 - PSNR_Metric: 28.0458
# Epoch 331/1000
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0017 - PSNR_Metric: 28.0477
# Epoch 332/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0017 - PSNR_Metric: 28.0496
# Epoch 333/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0017 - PSNR_Metric: 28.0515
# Epoch 334/1000
# 1/1 [==============================] - 1s 637ms/step - loss: 0.0017 - PSNR_Metric: 28.0535
# Epoch 335/1000
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0017 - PSNR_Metric: 28.0553
# Epoch 336/1000
# 1/1 [==============================] - 1s 636ms/step - loss: 0.0017 - PSNR_Metric: 28.0571
# Epoch 337/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0017 - PSNR_Metric: 28.0591
# Epoch 338/1000
# 1/1 [==============================] - 1s 643ms/step - loss: 0.0017 - PSNR_Metric: 28.0610
# Epoch 339/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0017 - PSNR_Metric: 28.0628
# Epoch 340/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0017 - PSNR_Metric: 28.0646
# Epoch 341/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0017 - PSNR_Metric: 28.0667
# Epoch 342/1000
# 1/1 [==============================] - 1s 646ms/step - loss: 0.0017 - PSNR_Metric: 28.0686
# Epoch 343/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0017 - PSNR_Metric: 28.0705
# Epoch 344/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0017 - PSNR_Metric: 28.0723
# Epoch 345/1000
# 1/1 [==============================] - 1s 643ms/step - loss: 0.0017 - PSNR_Metric: 28.0742
# Epoch 346/1000
# 1/1 [==============================] - 1s 646ms/step - loss: 0.0017 - PSNR_Metric: 28.0762
# Epoch 347/1000
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0017 - PSNR_Metric: 28.0780
# Epoch 348/1000
# 1/1 [==============================] - 1s 636ms/step - loss: 0.0017 - PSNR_Metric: 28.0798
# Epoch 349/1000
# 1/1 [==============================] - 1s 637ms/step - loss: 0.0017 - PSNR_Metric: 28.0817
# Epoch 350/1000
# 1/1 [==============================] - 1s 635ms/step - loss: 0.0017 - PSNR_Metric: 28.0836
# Epoch 351/1000
# 1/1 [==============================] - 1s 634ms/step - loss: 0.0017 - PSNR_Metric: 28.0855
# Epoch 352/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0017 - PSNR_Metric: 28.0873
# Epoch 353/1000
# 1/1 [==============================] - 1s 636ms/step - loss: 0.0017 - PSNR_Metric: 28.0893
# Epoch 354/1000
# 1/1 [==============================] - 1s 637ms/step - loss: 0.0017 - PSNR_Metric: 28.0912
# Epoch 355/1000
# 1/1 [==============================] - 1s 637ms/step - loss: 0.0017 - PSNR_Metric: 28.0930
# Epoch 356/1000
# 1/1 [==============================] - 1s 638ms/step - loss: 0.0017 - PSNR_Metric: 28.0950
# Epoch 357/1000
# 1/1 [==============================] - 1s 638ms/step - loss: 0.0017 - PSNR_Metric: 28.0969
# Epoch 358/1000
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0017 - PSNR_Metric: 28.0987
# Epoch 359/1000
# 1/1 [==============================] - 1s 647ms/step - loss: 0.0017 - PSNR_Metric: 28.1005
# Epoch 360/1000
# 1/1 [==============================] - 1s 636ms/step - loss: 0.0017 - PSNR_Metric: 28.1024
# Epoch 361/1000
# 1/1 [==============================] - 1s 643ms/step - loss: 0.0017 - PSNR_Metric: 28.1043
# Epoch 362/1000
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0017 - PSNR_Metric: 28.1060
# Epoch 363/1000
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0017 - PSNR_Metric: 28.1079
# Epoch 364/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0017 - PSNR_Metric: 28.1098
# Epoch 365/1000
# 1/1 [==============================] - 1s 637ms/step - loss: 0.0017 - PSNR_Metric: 28.1117
# Epoch 366/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0017 - PSNR_Metric: 28.1135
# Epoch 367/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0017 - PSNR_Metric: 28.1154
# Epoch 368/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0017 - PSNR_Metric: 28.1173
# Epoch 369/1000
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0017 - PSNR_Metric: 28.1191
# Epoch 370/1000
# 1/1 [==============================] - 1s 637ms/step - loss: 0.0017 - PSNR_Metric: 28.1209
# Epoch 371/1000
# 1/1 [==============================] - 1s 649ms/step - loss: 0.0017 - PSNR_Metric: 28.1227
# Epoch 372/1000
# 1/1 [==============================] - 1s 645ms/step - loss: 0.0017 - PSNR_Metric: 28.1246
# Epoch 373/1000
# 1/1 [==============================] - 1s 636ms/step - loss: 0.0017 - PSNR_Metric: 28.1264
# Epoch 374/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0017 - PSNR_Metric: 28.1281
# Epoch 375/1000
# 1/1 [==============================] - 1s 643ms/step - loss: 0.0017 - PSNR_Metric: 28.1301
# Epoch 376/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0017 - PSNR_Metric: 28.1320
# Epoch 377/1000
# 1/1 [==============================] - 1s 643ms/step - loss: 0.0017 - PSNR_Metric: 28.1338
# Epoch 378/1000
# 1/1 [==============================] - 1s 642ms/step - loss: 0.0017 - PSNR_Metric: 28.1357
# Epoch 379/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0017 - PSNR_Metric: 28.1377
# Epoch 380/1000
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0017 - PSNR_Metric: 28.1395
# Epoch 381/1000
# 1/1 [==============================] - 1s 650ms/step - loss: 0.0017 - PSNR_Metric: 28.1412
# Epoch 382/1000
# 1/1 [==============================] - 1s 642ms/step - loss: 0.0017 - PSNR_Metric: 28.1431
# Epoch 383/1000
# 1/1 [==============================] - 1s 642ms/step - loss: 0.0017 - PSNR_Metric: 28.1449
# Epoch 384/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0017 - PSNR_Metric: 28.1467
# Epoch 385/1000
# 1/1 [==============================] - 1s 645ms/step - loss: 0.0017 - PSNR_Metric: 28.1485
# Epoch 386/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0017 - PSNR_Metric: 28.1504
# Epoch 387/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0017 - PSNR_Metric: 28.1522
# Epoch 388/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0017 - PSNR_Metric: 28.1539
# Epoch 389/1000
# 1/1 [==============================] - 1s 648ms/step - loss: 0.0017 - PSNR_Metric: 28.1558
# Epoch 390/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0017 - PSNR_Metric: 28.1576
# Epoch 391/1000
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0017 - PSNR_Metric: 28.1594
# Epoch 392/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0017 - PSNR_Metric: 28.1613
# Epoch 393/1000
# 1/1 [==============================] - 1s 642ms/step - loss: 0.0017 - PSNR_Metric: 28.1632
# Epoch 394/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0017 - PSNR_Metric: 28.1650
# Epoch 395/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0017 - PSNR_Metric: 28.1668
# Epoch 396/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0017 - PSNR_Metric: 28.1687
# Epoch 397/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0017 - PSNR_Metric: 28.1705
# Epoch 398/1000
# 1/1 [==============================] - 1s 645ms/step - loss: 0.0017 - PSNR_Metric: 28.1723
# Epoch 399/1000
# 1/1 [==============================] - 1s 643ms/step - loss: 0.0017 - PSNR_Metric: 28.1741
# Epoch 400/1000
# 1/1 [==============================] - 1s 638ms/step - loss: 0.0017 - PSNR_Metric: 28.1760
# Epoch 401/1000
# 1/1 [==============================] - 1s 638ms/step - loss: 0.0017 - PSNR_Metric: 28.1779
# Epoch 402/1000
# 1/1 [==============================] - 1s 645ms/step - loss: 0.0017 - PSNR_Metric: 28.1796
# Epoch 403/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0017 - PSNR_Metric: 28.1814
# Epoch 404/1000
# 1/1 [==============================] - 1s 638ms/step - loss: 0.0017 - PSNR_Metric: 28.1833
# Epoch 405/1000
# 1/1 [==============================] - 1s 638ms/step - loss: 0.0017 - PSNR_Metric: 28.1851
# Epoch 406/1000
# 1/1 [==============================] - 1s 636ms/step - loss: 0.0017 - PSNR_Metric: 28.1869
# Epoch 407/1000
# 1/1 [==============================] - 1s 645ms/step - loss: 0.0017 - PSNR_Metric: 28.1887
# Epoch 408/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0017 - PSNR_Metric: 28.1905
# Epoch 409/1000
# 1/1 [==============================] - 1s 642ms/step - loss: 0.0017 - PSNR_Metric: 28.1923
# Epoch 410/1000
# 1/1 [==============================] - 1s 649ms/step - loss: 0.0017 - PSNR_Metric: 28.1941
# Epoch 411/1000
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0017 - PSNR_Metric: 28.1959
# Epoch 412/1000
# 1/1 [==============================] - 1s 646ms/step - loss: 0.0017 - PSNR_Metric: 28.1978
# Epoch 413/1000
# 1/1 [==============================] - 1s 642ms/step - loss: 0.0017 - PSNR_Metric: 28.1997
# Epoch 414/1000
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0017 - PSNR_Metric: 28.2016
# Epoch 415/1000
# 1/1 [==============================] - 1s 645ms/step - loss: 0.0017 - PSNR_Metric: 28.2035
# Epoch 416/1000
# 1/1 [==============================] - 1s 648ms/step - loss: 0.0017 - PSNR_Metric: 28.2053
# Epoch 417/1000
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0017 - PSNR_Metric: 28.2072
# Epoch 418/1000
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0017 - PSNR_Metric: 28.2090
# Epoch 419/1000
# 1/1 [==============================] - 1s 645ms/step - loss: 0.0017 - PSNR_Metric: 28.2107
# Epoch 420/1000
# 1/1 [==============================] - 1s 638ms/step - loss: 0.0017 - PSNR_Metric: 28.2126
# Epoch 421/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0017 - PSNR_Metric: 28.2145
# Epoch 422/1000
# 1/1 [==============================] - 1s 637ms/step - loss: 0.0017 - PSNR_Metric: 28.2163
# Epoch 423/1000
# 1/1 [==============================] - 1s 642ms/step - loss: 0.0017 - PSNR_Metric: 28.2182
# Epoch 424/1000
# 1/1 [==============================] - 1s 647ms/step - loss: 0.0017 - PSNR_Metric: 28.2201
# Epoch 425/1000
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0017 - PSNR_Metric: 28.2219
# Epoch 426/1000
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0017 - PSNR_Metric: 28.2238
# Epoch 427/1000
# 1/1 [==============================] - 1s 642ms/step - loss: 0.0017 - PSNR_Metric: 28.2257
# Epoch 428/1000
# 1/1 [==============================] - 1s 643ms/step - loss: 0.0017 - PSNR_Metric: 28.2276
# Epoch 429/1000
# 1/1 [==============================] - 1s 646ms/step - loss: 0.0017 - PSNR_Metric: 28.2294
# Epoch 430/1000
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0017 - PSNR_Metric: 28.2312
# Epoch 431/1000
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0017 - PSNR_Metric: 28.2331
# Epoch 432/1000
# 1/1 [==============================] - 1s 651ms/step - loss: 0.0017 - PSNR_Metric: 28.2350
# Epoch 433/1000
# 1/1 [==============================] - 1s 637ms/step - loss: 0.0017 - PSNR_Metric: 28.2368
# Epoch 434/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0017 - PSNR_Metric: 28.2387
# Epoch 435/1000
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0017 - PSNR_Metric: 28.2406
# Epoch 436/1000
# 1/1 [==============================] - 1s 637ms/step - loss: 0.0017 - PSNR_Metric: 28.2425
# Epoch 437/1000
# 1/1 [==============================] - 1s 646ms/step - loss: 0.0017 - PSNR_Metric: 28.2444
# Epoch 438/1000
# 1/1 [==============================] - 1s 647ms/step - loss: 0.0017 - PSNR_Metric: 28.2462
# Epoch 439/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0017 - PSNR_Metric: 28.2482
# Epoch 440/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0017 - PSNR_Metric: 28.2501
# Epoch 441/1000
# 1/1 [==============================] - 1s 643ms/step - loss: 0.0017 - PSNR_Metric: 28.2520
# Epoch 442/1000
# 1/1 [==============================] - 1s 648ms/step - loss: 0.0017 - PSNR_Metric: 28.2538
# Epoch 443/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0017 - PSNR_Metric: 28.2557
# Epoch 444/1000
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0017 - PSNR_Metric: 28.2576
# Epoch 445/1000
# 1/1 [==============================] - 1s 638ms/step - loss: 0.0017 - PSNR_Metric: 28.2595
# Epoch 446/1000
# 1/1 [==============================] - 1s 645ms/step - loss: 0.0017 - PSNR_Metric: 28.2614
# Epoch 447/1000
# 1/1 [==============================] - 1s 649ms/step - loss: 0.0017 - PSNR_Metric: 28.2634
# Epoch 448/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0017 - PSNR_Metric: 28.2653
# Epoch 449/1000
# 1/1 [==============================] - 1s 650ms/step - loss: 0.0017 - PSNR_Metric: 28.2673
# Epoch 450/1000
# 1/1 [==============================] - 1s 642ms/step - loss: 0.0017 - PSNR_Metric: 28.2692
# Epoch 451/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0017 - PSNR_Metric: 28.2712
# Epoch 452/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0017 - PSNR_Metric: 28.2731
# Epoch 453/1000
# 1/1 [==============================] - 1s 643ms/step - loss: 0.0017 - PSNR_Metric: 28.2750
# Epoch 454/1000
# ...
# Epoch 851/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0013 - PSNR_Metric: 29.3260
# Epoch 852/1000
# 1/1 [==============================] - 1s 650ms/step - loss: 0.0013 - PSNR_Metric: 29.3275
# Epoch 853/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0013 - PSNR_Metric: 29.3280
# Epoch 854/1000
# 1/1 [==============================] - 1s 643ms/step - loss: 0.0013 - PSNR_Metric: 29.3299
# Epoch 855/1000
# 1/1 [==============================] - 1s 642ms/step - loss: 0.0013 - PSNR_Metric: 29.3297
# Epoch 856/1000
# 1/1 [==============================] - 1s 636ms/step - loss: 0.0013 - PSNR_Metric: 29.3336
# Epoch 857/1000
# 1/1 [==============================] - 1s 646ms/step - loss: 0.0013 - PSNR_Metric: 29.3359
# Epoch 858/1000
# 1/1 [==============================] - 1s 646ms/step - loss: 0.0013 - PSNR_Metric: 29.3403
# Epoch 859/1000
# 1/1 [==============================] - 1s 646ms/step - loss: 0.0013 - PSNR_Metric: 29.3440
# Epoch 860/1000
# 1/1 [==============================] - 1s 645ms/step - loss: 0.0013 - PSNR_Metric: 29.3473
# Epoch 861/1000
# 1/1 [==============================] - 1s 637ms/step - loss: 0.0013 - PSNR_Metric: 29.3493
# Epoch 862/1000
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0013 - PSNR_Metric: 29.3513
# Epoch 863/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0013 - PSNR_Metric: 29.3532
# Epoch 864/1000
# 1/1 [==============================] - 1s 653ms/step - loss: 0.0013 - PSNR_Metric: 29.3535
# Epoch 865/1000
# 1/1 [==============================] - 1s 648ms/step - loss: 0.0013 - PSNR_Metric: 29.3552
# Epoch 866/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0013 - PSNR_Metric: 29.3555
# Epoch 867/1000
# 1/1 [==============================] - 1s 648ms/step - loss: 0.0013 - PSNR_Metric: 29.3580
# Epoch 868/1000
# 1/1 [==============================] - 1s 651ms/step - loss: 0.0013 - PSNR_Metric: 29.3603
# Epoch 869/1000
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0013 - PSNR_Metric: 29.3650
# Epoch 870/1000
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0013 - PSNR_Metric: 29.3678
# Epoch 871/1000
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0013 - PSNR_Metric: 29.3715
# Epoch 872/1000
# 1/1 [==============================] - 1s 637ms/step - loss: 0.0013 - PSNR_Metric: 29.3739
# Epoch 873/1000
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0013 - PSNR_Metric: 29.3751
# Epoch 874/1000
# 1/1 [==============================] - 1s 652ms/step - loss: 0.0013 - PSNR_Metric: 29.3770
# Epoch 875/1000
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0013 - PSNR_Metric: 29.3775
# Epoch 876/1000
# 1/1 [==============================] - 1s 646ms/step - loss: 0.0013 - PSNR_Metric: 29.3788
# Epoch 877/1000
# 1/1 [==============================] - 1s 646ms/step - loss: 0.0013 - PSNR_Metric: 29.3801
# Epoch 878/1000
# 1/1 [==============================] - 1s 648ms/step - loss: 0.0013 - PSNR_Metric: 29.3834
# Epoch 879/1000
# 1/1 [==============================] - 1s 642ms/step - loss: 0.0013 - PSNR_Metric: 29.3853
# Epoch 880/1000
# 1/1 [==============================] - 1s 643ms/step - loss: 0.0013 - PSNR_Metric: 29.3896
# Epoch 881/1000
# 1/1 [==============================] - 1s 650ms/step - loss: 0.0013 - PSNR_Metric: 29.3921
# Epoch 882/1000
# 1/1 [==============================] - 1s 645ms/step - loss: 0.0013 - PSNR_Metric: 29.3945
# Epoch 883/1000
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0013 - PSNR_Metric: 29.3972
# Epoch 884/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0013 - PSNR_Metric: 29.3989
# Epoch 885/1000
# 1/1 [==============================] - 1s 647ms/step - loss: 0.0013 - PSNR_Metric: 29.4006
# Epoch 886/1000
# 1/1 [==============================] - 1s 649ms/step - loss: 0.0013 - PSNR_Metric: 29.4019
# Epoch 887/1000
# 1/1 [==============================] - 1s 645ms/step - loss: 0.0013 - PSNR_Metric: 29.4031
# Epoch 888/1000
# 1/1 [==============================] - 1s 646ms/step - loss: 0.0013 - PSNR_Metric: 29.4040
# Epoch 889/1000
# 1/1 [==============================] - 1s 652ms/step - loss: 0.0013 - PSNR_Metric: 29.4060
# Epoch 890/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0013 - PSNR_Metric: 29.4064
# Epoch 891/1000
# 1/1 [==============================] - 1s 651ms/step - loss: 0.0013 - PSNR_Metric: 29.4099
# Epoch 892/1000
# 1/1 [==============================] - 1s 637ms/step - loss: 0.0013 - PSNR_Metric: 29.4121
# Epoch 893/1000
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0013 - PSNR_Metric: 29.4157
# Epoch 894/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0013 - PSNR_Metric: 29.4190
# Epoch 895/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0013 - PSNR_Metric: 29.4217
# Epoch 896/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0013 - PSNR_Metric: 29.4234
# Epoch 897/1000
# 1/1 [==============================] - 1s 645ms/step - loss: 0.0013 - PSNR_Metric: 29.4249
# Epoch 898/1000
# 1/1 [==============================] - 1s 651ms/step - loss: 0.0013 - PSNR_Metric: 29.4260
# Epoch 899/1000
# 1/1 [==============================] - 1s 646ms/step - loss: 0.0013 - PSNR_Metric: 29.4266
# Epoch 900/1000
# 1/1 [==============================] - 1s 642ms/step - loss: 0.0013 - PSNR_Metric: 29.4288
# Epoch 901/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0013 - PSNR_Metric: 29.4299
# Epoch 902/1000
# 1/1 [==============================] - 1s 646ms/step - loss: 0.0013 - PSNR_Metric: 29.4335
# Epoch 903/1000
# 1/1 [==============================] - 1s 648ms/step - loss: 0.0013 - PSNR_Metric: 29.4360
# Epoch 904/1000
# 1/1 [==============================] - 1s 646ms/step - loss: 0.0013 - PSNR_Metric: 29.4387
# Epoch 905/1000
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0013 - PSNR_Metric: 29.4414
# Epoch 906/1000
# 1/1 [==============================] - 1s 643ms/step - loss: 0.0013 - PSNR_Metric: 29.4434
# Epoch 907/1000
# 1/1 [==============================] - 1s 646ms/step - loss: 0.0013 - PSNR_Metric: 29.4451
# Epoch 908/1000
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0013 - PSNR_Metric: 29.4467
# Epoch 909/1000
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0012 - PSNR_Metric: 29.4478
# Epoch 910/1000
# 1/1 [==============================] - 1s 647ms/step - loss: 0.0012 - PSNR_Metric: 29.4486
# Epoch 911/1000
# 1/1 [==============================] - 1s 642ms/step - loss: 0.0012 - PSNR_Metric: 29.4499
# Epoch 912/1000
# 1/1 [==============================] - 1s 642ms/step - loss: 0.0012 - PSNR_Metric: 29.4498
# Epoch 913/1000
# 1/1 [==============================] - 1s 650ms/step - loss: 0.0012 - PSNR_Metric: 29.4526
# Epoch 914/1000
# 1/1 [==============================] - 1s 645ms/step - loss: 0.0012 - PSNR_Metric: 29.4537
# Epoch 915/1000
# 1/1 [==============================] - 1s 643ms/step - loss: 0.0012 - PSNR_Metric: 29.4572
# Epoch 916/1000
# 1/1 [==============================] - 1s 643ms/step - loss: 0.0012 - PSNR_Metric: 29.4604
# Epoch 917/1000
# 1/1 [==============================] - 1s 637ms/step - loss: 0.0012 - PSNR_Metric: 29.4639
# Epoch 918/1000
# 1/1 [==============================] - 1s 642ms/step - loss: 0.0012 - PSNR_Metric: 29.4660
# Epoch 919/1000
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0012 - PSNR_Metric: 29.4679
# Epoch 920/1000
# 1/1 [==============================] - 1s 643ms/step - loss: 0.0012 - PSNR_Metric: 29.4689
# Epoch 921/1000
# 1/1 [==============================] - 1s 648ms/step - loss: 0.0012 - PSNR_Metric: 29.4691
# Epoch 922/1000
# 1/1 [==============================] - 1s 646ms/step - loss: 0.0012 - PSNR_Metric: 29.4705
# Epoch 923/1000
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0012 - PSNR_Metric: 29.4709
# Epoch 924/1000
# 1/1 [==============================] - 1s 647ms/step - loss: 0.0012 - PSNR_Metric: 29.4744
# Epoch 925/1000
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0012 - PSNR_Metric: 29.4768
# Epoch 926/1000
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0012 - PSNR_Metric: 29.4800
# Epoch 927/1000
# 1/1 [==============================] - 1s 638ms/step - loss: 0.0012 - PSNR_Metric: 29.4828
# Epoch 928/1000
# 1/1 [==============================] - 1s 648ms/step - loss: 0.0012 - PSNR_Metric: 29.4848
# Epoch 929/1000
# 1/1 [==============================] - 1s 642ms/step - loss: 0.0012 - PSNR_Metric: 29.4865
# Epoch 930/1000
# 1/1 [==============================] - 1s 638ms/step - loss: 0.0012 - PSNR_Metric: 29.4879
# Epoch 931/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0012 - PSNR_Metric: 29.4894
# Epoch 932/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0012 - PSNR_Metric: 29.4904
# Epoch 933/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0012 - PSNR_Metric: 29.4924
# Epoch 934/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0012 - PSNR_Metric: 29.4934
# Epoch 935/1000
# 1/1 [==============================] - 1s 642ms/step - loss: 0.0012 - PSNR_Metric: 29.4957
# Epoch 936/1000
# 1/1 [==============================] - 1s 647ms/step - loss: 0.0012 - PSNR_Metric: 29.4969
# Epoch 937/1000
# 1/1 [==============================] - 1s 645ms/step - loss: 0.0012 - PSNR_Metric: 29.4994
# Epoch 938/1000
# 1/1 [==============================] - 1s 650ms/step - loss: 0.0012 - PSNR_Metric: 29.5007
# Epoch 939/1000
# 1/1 [==============================] - 1s 635ms/step - loss: 0.0012 - PSNR_Metric: 29.5031
# Epoch 940/1000
# 1/1 [==============================] - 1s 652ms/step - loss: 0.0012 - PSNR_Metric: 29.5049
# Epoch 941/1000
# 1/1 [==============================] - 1s 642ms/step - loss: 0.0012 - PSNR_Metric: 29.5077
# Epoch 942/1000
# 1/1 [==============================] - 1s 643ms/step - loss: 0.0012 - PSNR_Metric: 29.5095
# Epoch 943/1000
# 1/1 [==============================] - 1s 642ms/step - loss: 0.0012 - PSNR_Metric: 29.5117
# Epoch 944/1000
# 1/1 [==============================] - 1s 652ms/step - loss: 0.0012 - PSNR_Metric: 29.5134
# Epoch 945/1000
# 1/1 [==============================] - 1s 646ms/step - loss: 0.0012 - PSNR_Metric: 29.5151
# Epoch 946/1000
# 1/1 [==============================] - 1s 643ms/step - loss: 0.0012 - PSNR_Metric: 29.5167
# Epoch 947/1000
# 1/1 [==============================] - 1s 642ms/step - loss: 0.0012 - PSNR_Metric: 29.5173
# Epoch 948/1000
# 1/1 [==============================] - 1s 645ms/step - loss: 0.0012 - PSNR_Metric: 29.5184
# Epoch 949/1000
# 1/1 [==============================] - 1s 642ms/step - loss: 0.0012 - PSNR_Metric: 29.5179
# Epoch 950/1000
# 1/1 [==============================] - 1s 643ms/step - loss: 0.0012 - PSNR_Metric: 29.5181
# Epoch 951/1000
# 1/1 [==============================] - 1s 646ms/step - loss: 0.0012 - PSNR_Metric: 29.5173
# Epoch 952/1000
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0012 - PSNR_Metric: 29.5206
# Epoch 953/1000
# 1/1 [==============================] - 1s 645ms/step - loss: 0.0012 - PSNR_Metric: 29.5229
# Epoch 954/1000
# 1/1 [==============================] - 1s 635ms/step - loss: 0.0012 - PSNR_Metric: 29.5285
# Epoch 955/1000
# 1/1 [==============================] - 1s 646ms/step - loss: 0.0012 - PSNR_Metric: 29.5317
# Epoch 956/1000
# 1/1 [==============================] - 1s 647ms/step - loss: 0.0012 - PSNR_Metric: 29.5343
# Epoch 957/1000
# 1/1 [==============================] - 1s 642ms/step - loss: 0.0012 - PSNR_Metric: 29.5359
# Epoch 958/1000
# 1/1 [==============================] - 1s 645ms/step - loss: 0.0012 - PSNR_Metric: 29.5360
# Epoch 959/1000
# 1/1 [==============================] - 1s 636ms/step - loss: 0.0012 - PSNR_Metric: 29.5372
# Epoch 960/1000
# 1/1 [==============================] - 1s 650ms/step - loss: 0.0012 - PSNR_Metric: 29.5380
# Epoch 961/1000
# 1/1 [==============================] - 1s 645ms/step - loss: 0.0012 - PSNR_Metric: 29.5403
# Epoch 962/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0012 - PSNR_Metric: 29.5425
# Epoch 963/1000
# 1/1 [==============================] - 1s 642ms/step - loss: 0.0012 - PSNR_Metric: 29.5458
# Epoch 964/1000
# 1/1 [==============================] - 1s 655ms/step - loss: 0.0012 - PSNR_Metric: 29.5477
# Epoch 965/1000
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0012 - PSNR_Metric: 29.5497
# Epoch 966/1000
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0012 - PSNR_Metric: 29.5512
# Epoch 967/1000
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0012 - PSNR_Metric: 29.5520
# Epoch 968/1000
# 1/1 [==============================] - 1s 637ms/step - loss: 0.0012 - PSNR_Metric: 29.5536
# Epoch 969/1000
# 1/1 [==============================] - 1s 645ms/step - loss: 0.0012 - PSNR_Metric: 29.5542
# Epoch 970/1000
# 1/1 [==============================] - 1s 642ms/step - loss: 0.0012 - PSNR_Metric: 29.5561
# Epoch 971/1000
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0012 - PSNR_Metric: 29.5569
# Epoch 972/1000
# 1/1 [==============================] - 1s 648ms/step - loss: 0.0012 - PSNR_Metric: 29.5595
# Epoch 973/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0012 - PSNR_Metric: 29.5610
# Epoch 974/1000
# 1/1 [==============================] - 1s 649ms/step - loss: 0.0012 - PSNR_Metric: 29.5635
# Epoch 975/1000
# 1/1 [==============================] - 1s 642ms/step - loss: 0.0012 - PSNR_Metric: 29.5653
# Epoch 976/1000
# 1/1 [==============================] - 1s 648ms/step - loss: 0.0012 - PSNR_Metric: 29.5679
# Epoch 977/1000
# 1/1 [==============================] - 1s 642ms/step - loss: 0.0012 - PSNR_Metric: 29.5696
# Epoch 978/1000
# 1/1 [==============================] - 1s 642ms/step - loss: 0.0012 - PSNR_Metric: 29.5715
# Epoch 979/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0012 - PSNR_Metric: 29.5731
# Epoch 980/1000
# 1/1 [==============================] - 1s 637ms/step - loss: 0.0012 - PSNR_Metric: 29.5746
# Epoch 981/1000
# 1/1 [==============================] - 1s 642ms/step - loss: 0.0012 - PSNR_Metric: 29.5761
# Epoch 982/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0012 - PSNR_Metric: 29.5771
# Epoch 983/1000
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0012 - PSNR_Metric: 29.5784
# Epoch 984/1000
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0012 - PSNR_Metric: 29.5779
# Epoch 985/1000
# 1/1 [==============================] - 1s 645ms/step - loss: 0.0012 - PSNR_Metric: 29.5784
# Epoch 986/1000
# 1/1 [==============================] - 1s 638ms/step - loss: 0.0012 - PSNR_Metric: 29.5766
# Epoch 987/1000
# 1/1 [==============================] - 1s 647ms/step - loss: 0.0012 - PSNR_Metric: 29.5780
# Epoch 988/1000
# 1/1 [==============================] - 1s 656ms/step - loss: 0.0012 - PSNR_Metric: 29.5774
# Epoch 989/1000
# 1/1 [==============================] - 1s 650ms/step - loss: 0.0012 - PSNR_Metric: 29.5832
# Epoch 990/1000
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0012 - PSNR_Metric: 29.5870
# Epoch 991/1000
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0012 - PSNR_Metric: 29.5924
# Epoch 992/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0012 - PSNR_Metric: 29.5942
# Epoch 993/1000
# 1/1 [==============================] - 1s 642ms/step - loss: 0.0012 - PSNR_Metric: 29.5937
# Epoch 994/1000
# 1/1 [==============================] - 1s 648ms/step - loss: 0.0012 - PSNR_Metric: 29.5942
# Epoch 995/1000
# 1/1 [==============================] - 1s 637ms/step - loss: 0.0012 - PSNR_Metric: 29.5936
# Epoch 996/1000
# 1/1 [==============================] - 1s 651ms/step - loss: 0.0012 - PSNR_Metric: 29.5964
# Epoch 997/1000
# 1/1 [==============================] - 1s 646ms/step - loss: 0.0012 - PSNR_Metric: 29.5987
# Epoch 998/1000
# 1/1 [==============================] - 1s 642ms/step - loss: 0.0012 - PSNR_Metric: 29.6030
# Epoch 999/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0012 - PSNR_Metric: 29.6054
# Epoch 1000/1000
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0012 - PSNR_Metric: 29.6066
# VarianceScaling_NoPadd_Batch, 29.606597900390625, 0.0012034879764541984, 1000.h5
